# %%
import sys
print(sys.version)
print("test")
# Out:
# 3.8.12 (default, Oct 12 2021, 13:49:34)
# [GCC 7.5.0]
# test

# %%
# Tensor类型转化
import torch
from torch import nn


class Tudui(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input):
        output = input + 1
        return output


tudui = Tudui()
# 转化成tensor类型
x = torch.tensor(1.0)
output = tudui(x)
print(output)
# Out:
# tensor(2.)

# %%
# 二维卷积神经网络原理

import torch
import torch.nn.functional as F

# 输入
input = torch.tensor([[1, 2, 0, 3, 1],
                      [0, 1, 2, 3, 1],
                      [1, 2, 1, 0, 0],
                      [5, 2, 3, 1, 1],
                      [2, 1, 0, 1, 1]])

# 卷积核
kernel = torch.tensor([[1, 2, 1],
                       [0, 1, 0],
                       [2, 1, 0]])

input = torch.reshape(input, (1, 1, 5, 5))
kernel = torch.reshape(kernel, (1, 1, 3, 3))

# 查看尺寸
print(input.shape)
print(kernel.shape)

output = F.conv2d(input, kernel, stride=1)
print(output)

output2 = F.conv2d(input, kernel, stride=2)
print(output2)

# padding进行填充（扩充原矩阵）
output3 = F.conv2d(input, kernel, stride=1, padding=1)
print(output3)
# Out:
# torch.Size([1, 1, 5, 5])
# torch.Size([1, 1, 3, 3])
# tensor([[[[10, 12, 12],
#           [18, 16, 16],
#           [13,  9,  3]]]])
# tensor([[[[10, 12],
#           [13,  3]]]])
# tensor([[[[ 1,  3,  4, 10,  8],
#           [ 5, 10, 12, 12,  6],
#           [ 7, 18, 16, 16,  8],
#           [11, 13,  9,  3,  4],
#           [14, 13,  9,  7,  4]]]])

# %%
# 二维神经网络
import torch
import torchvision
from torch import nn
from torch.nn import Conv2d
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

dataset = torchvision.datasets.CIFAR10(
    "./dataset", train=False, transform=torchvision.transforms.ToTensor(), download=True)
# 放入DataLoader
dataloader = DataLoader(dataset, batch_size=64)


class nn2d(nn.Module):
    def __init__(self):
        super(nn2d, self).__init__()
        # 卷积层1
        self.conv1 = Conv2d(in_channels=3, out_channels=6,
                            kernel_size=3, stride=1, padding=0)

    # 传入下一层
    def forward(self, x):
        x = self.conv1(x)
        return x


tudui = nn2d()

# 写入TensorBoard
writer = SummaryWriter("./logs")

step = 0
for data in dataloader:
    imgs, targets = data
    output = tudui(imgs)
    print(imgs.shape)
    print(output.shape)
    # torch.Size([64, 3, 32, 32])
    writer.add_images("input", imgs, step)
    # torch.Size([64, 6, 30, 30])  -> [xxx, 3, 30, 30]
    # 6通道变3通道
    # -1自动补上
    output = torch.reshape(output, (-1, 3, 30, 30))
    writer.add_images("output", output, step)

    step = step + 1

writer.close()
# Out:
# Files already downloaded and verified
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([64, 3, 32, 32])
# torch.Size([64, 6, 30, 30])
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 6, 30, 30])

# %%
# 池化层（即保留特征的同时降维）

import torch
import torchvision
from torch import nn
from torch.nn import MaxPool2d
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

dataset = torchvision.datasets.CIFAR10("./dataset", train=False, download=True,
                                       transform=torchvision.transforms.ToTensor())

dataloader = DataLoader(dataset, batch_size=64)


class nnMaxpool(nn.Module):
    def __init__(self):
        super(nnMaxpool, self).__init__()
        self.maxpool1 = MaxPool2d(kernel_size=3, ceil_mode=False)

    def forward(self, input):
        output = self.maxpool1(input)
        return output


tudui = nnMaxpool()

writer = SummaryWriter("./logs_maxpool")
step = 0
for data in dataloader:
    imgs, targets = data
    writer.add_images("input", imgs, step)
    output = tudui(imgs)
    writer.add_images("output", output, step)
    step = step + 1

writer.close()
# Out:
# Files already downloaded and verified

# %%
# 非线性激活函数

import torch
import torchvision
from torch import nn
from torch.nn import ReLU, Sigmoid
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

input = torch.tensor([[1, -0.5],
                      [-1, 3]])

input = torch.reshape(input, (-1, 1, 2, 2))
print(input.shape)

dataset = torchvision.datasets.CIFAR10("./dataset", train=False, download=True,
                                       transform=torchvision.transforms.ToTensor())

dataloader = DataLoader(dataset, batch_size=64)


class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.relu1 = ReLU()
        # 采用SIGMOD激活函数
        self.sigmoid1 = Sigmoid()

    def forward(self, input):
        output = self.sigmoid1(input)
        return output


tudui = Tudui()

writer = SummaryWriter("./logs_relu")
step = 0
for data in dataloader:
    imgs, targets = data
    writer.add_images("input", imgs, global_step=step)
    output = tudui(imgs)
    writer.add_images("output", output, step)
    step += 1

writer.close()
# Out:
# torch.Size([1, 1, 2, 2])
# Files already downloaded and verified

# %%
# -*- coding: utf-8 -*-
# 线性激活函数
import torch
import torchvision
from torch import nn
from torch.nn import Linear
from torch.utils.data import DataLoader

dataset = torchvision.datasets.CIFAR10("./dataset", train=False, transform=torchvision.transforms.ToTensor(),
                                       download=True)

dataloader = DataLoader(dataset, batch_size=64, drop_last=True)


class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.linear1 = Linear(196608, 10)

    def forward(self, input):
        output = self.linear1(input)
        return output


tudui = Tudui()

for data in dataloader:
    imgs, targets = data
    print(imgs.shape)
    output = torch.flatten(imgs)
    print(output.shape)
    output = tudui(output)
    print(output.shape)
# Out:
# Files already downloaded and verified
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])
# torch.Size([64, 3, 32, 32])
# torch.Size([196608])
# torch.Size([10])

# %%
# 损失函数
import torch
from torch.nn import L1Loss
from torch import nn

inputs = torch.tensor([1, 2, 3], dtype=torch.float32)
targets = torch.tensor([1, 2, 5], dtype=torch.float32)

inputs = torch.reshape(inputs, (1, 1, 1, 3))
targets = torch.reshape(targets, (1, 1, 1, 3))

loss = L1Loss(reduction='sum')
result = loss(inputs, targets)

loss_mse = nn.MSELoss()
result_mse = loss_mse(inputs, targets)

print(result)
print(result_mse)


x = torch.tensor([0.1, 0.2, 0.3])
y = torch.tensor([1])
x = torch.reshape(x, (1, 3))
loss_cross = nn.CrossEntropyLoss()
result_cross = loss_cross(x, y)
print(result_cross)
# Out:
# tensor(2.)
# tensor(1.3333)
# tensor(1.1019)

# %%
# loss函数在神经网络中的应用
import torchvision
from torch import nn
from torch.nn import Sequential, Conv2d, MaxPool2d, Flatten, Linear
from torch.utils.data import DataLoader

dataset = torchvision.datasets.CIFAR10("./dataset", train=False, transform=torchvision.transforms.ToTensor(),
                                       download=True)

dataloader = DataLoader(dataset, batch_size=1)


class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.model1 = Sequential(
            Conv2d(3, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024, 64),
            Linear(64, 10)
        )

    def forward(self, x):
        x = self.model1(x)
        return x


loss = nn.CrossEntropyLoss()
tudui = Tudui()
for data in dataloader:
    imgs, targets = data
    outputs = tudui(imgs)
    result_loss = loss(outputs, targets)
    print(outputs)
    print(targets)
    print(result_loss)
# Out:
# Files already downloaded and verified
# /home/tzr/anaconda3/envs/RockLab/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448234945/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# tensor([[-0.0127, -0.0005,  0.1205, -0.0044,  0.0105,  0.0165, -0.1121,  0.0883,
#          -0.1458,  0.0484]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3108, grad_fn=<NllLossBackward>)
# tensor([[ 0.0073,  0.0154,  0.0993, -0.0027,  0.0099,  0.0369, -0.1166,  0.0691,
#          -0.1598,  0.0240]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4634, grad_fn=<NllLossBackward>)
# tensor([[-0.0050, -0.0096,  0.1016, -0.0064,  0.0034,  0.0288, -0.1004,  0.0673,
#          -0.1681,  0.0289]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4674, grad_fn=<NllLossBackward>)
# tensor([[-0.0118,  0.0128,  0.1151,  0.0044,  0.0078,  0.0487, -0.1138,  0.0711,
#          -0.1622,  0.0351]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3182, grad_fn=<NllLossBackward>)
# tensor([[-0.0082,  0.0101,  0.1249,  0.0161,  0.0138,  0.0305, -0.1201,  0.0774,
#          -0.1464,  0.0311]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4285, grad_fn=<NllLossBackward>)
# tensor([[ 0.0049,  0.0006,  0.1080, -0.0160,  0.0229,  0.0084, -0.1168,  0.0852,
#          -0.1473,  0.0400]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4211, grad_fn=<NllLossBackward>)
# tensor([[-0.0188, -0.0014,  0.1428,  0.0035,  0.0052,  0.0119, -0.1160,  0.0926,
#          -0.1511,  0.0397]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3081, grad_fn=<NllLossBackward>)
# tensor([[-0.0041,  0.0088,  0.1083, -0.0077,  0.0326,  0.0112, -0.1142,  0.0798,
#          -0.1474,  0.0353]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4197, grad_fn=<NllLossBackward>)
# tensor([[-0.0089,  0.0100,  0.1142,  0.0324, -0.0057,  0.0598, -0.1163,  0.0796,
#          -0.1462,  0.0287]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2779, grad_fn=<NllLossBackward>)
# tensor([[ 0.0014,  0.0051,  0.1039,  0.0284,  0.0221,  0.0296, -0.1022,  0.0840,
#          -0.1485,  0.0177]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3042, grad_fn=<NllLossBackward>)
# tensor([[-0.0127,  0.0040,  0.1160,  0.0136, -0.0019,  0.0390, -0.1181,  0.0679,
#          -0.1497,  0.0254]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3165, grad_fn=<NllLossBackward>)
# tensor([[-0.0007, -0.0075,  0.1091, -0.0063,  0.0190,  0.0155, -0.1060,  0.0735,
#          -0.1517,  0.0240]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2781, grad_fn=<NllLossBackward>)
# tensor([[-0.0174,  0.0035,  0.1474,  0.0033,  0.0020,  0.0381, -0.1149,  0.0979,
#          -0.1529,  0.0498]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2737, grad_fn=<NllLossBackward>)
# tensor([[-0.0037,  0.0003,  0.1598, -0.0115, -0.0096,  0.0306, -0.1333,  0.0783,
#          -0.1478,  0.0614]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2305, grad_fn=<NllLossBackward>)
# tensor([[ 0.0002, -0.0009,  0.1192,  0.0094,  0.0177,  0.0100, -0.1148,  0.0924,
#          -0.1434,  0.0249]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2820, grad_fn=<NllLossBackward>)
# tensor([[-0.0063,  0.0204,  0.1214,  0.0045, -0.0026,  0.0363, -0.1124,  0.0809,
#          -0.1593,  0.0320]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4664, grad_fn=<NllLossBackward>)
# tensor([[-0.0151, -0.0079,  0.1290,  0.0036, -0.0205,  0.0376, -0.1031,  0.0697,
#          -0.1411,  0.0573]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2688, grad_fn=<NllLossBackward>)
# tensor([[ 0.0017,  0.0119,  0.1180,  0.0266,  0.0139,  0.0299, -0.1183,  0.1013,
#          -0.1361,  0.0158]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2107, grad_fn=<NllLossBackward>)
# tensor([[ 0.0073,  0.0030,  0.0913, -0.0079,  0.0130,  0.0225, -0.1243,  0.0682,
#          -0.1442,  0.0220]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4443, grad_fn=<NllLossBackward>)
# tensor([[-0.0057,  0.0090,  0.1349,  0.0071,  0.0042,  0.0452, -0.1272,  0.0849,
#          -0.1471,  0.0311]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4367, grad_fn=<NllLossBackward>)
# tensor([[ 0.0116,  0.0032,  0.1122,  0.0103,  0.0036,  0.0297, -0.1204,  0.0942,
#          -0.1512,  0.0186]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2125, grad_fn=<NllLossBackward>)
# tensor([[-0.0026,  0.0295,  0.1010,  0.0393,  0.0015,  0.1039, -0.1330,  0.1430,
#          -0.1813,  0.0022]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3201, grad_fn=<NllLossBackward>)
# tensor([[-0.0051, -0.0005,  0.1113,  0.0115,  0.0303,  0.0002, -0.1050,  0.0879,
#          -0.1359,  0.0154]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2758, grad_fn=<NllLossBackward>)
# tensor([[ 0.0062,  0.0128,  0.1270,  0.0149,  0.0321,  0.0129, -0.1188,  0.1045,
#          -0.1350,  0.0183]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor([[ 0.0134,  0.0133,  0.0983,  0.0098,  0.0257,  0.0309, -0.1306,  0.0849,
#          -0.1475,  0.0179]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2761, grad_fn=<NllLossBackward>)
# tensor([[ 0.0021, -0.0080,  0.1081, -0.0016,  0.0179,  0.0284, -0.1067,  0.0801,
#          -0.1493,  0.0411]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1984, grad_fn=<NllLossBackward>)
# tensor([[-0.0068,  0.0064,  0.1165,  0.0053,  0.0324,  0.0021, -0.1051,  0.0911,
#          -0.1430,  0.0153]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2743, grad_fn=<NllLossBackward>)
# tensor([[ 0.0061,  0.0117,  0.0993,  0.0070,  0.0106,  0.0269, -0.1146,  0.0890,
#          -0.1511,  0.0076]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.2984, grad_fn=<NllLossBackward>)
# tensor([[-0.0017,  0.0044,  0.1136,  0.0216,  0.0333,  0.0190, -0.1056,  0.0962,
#          -0.1459,  0.0147]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2956, grad_fn=<NllLossBackward>)
# tensor([[ 0.0032,  0.0030,  0.1058, -0.0063,  0.0346, -0.0007, -0.1173,  0.0762,
#          -0.1392,  0.0393]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4223, grad_fn=<NllLossBackward>)
# tensor([[-0.0099, -0.0052,  0.1079,  0.0003,  0.0407, -0.0151, -0.1039,  0.0826,
#          -0.1323,  0.0234]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4078, grad_fn=<NllLossBackward>)
# tensor([[ 0.0010,  0.0178,  0.1193,  0.0180,  0.0169,  0.0392, -0.1211,  0.0877,
#          -0.1441,  0.0131]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2711, grad_fn=<NllLossBackward>)
# tensor([[-0.0182,  0.0142,  0.1230,  0.0115,  0.0077,  0.0509, -0.1115,  0.0829,
#          -0.1543,  0.0337]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3020, grad_fn=<NllLossBackward>)
# tensor([[-0.0221, -0.0004,  0.1136,  0.0061,  0.0368,  0.0247, -0.1174,  0.0995,
#          -0.1446,  0.0440]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2849, grad_fn=<NllLossBackward>)
# tensor([[-0.0011, -0.0048,  0.1125,  0.0015,  0.0182,  0.0085, -0.1023,  0.0832,
#          -0.1558,  0.0215]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2819, grad_fn=<NllLossBackward>)
# tensor([[-0.0177,  0.0115,  0.1150, -0.0109,  0.0153,  0.0096, -0.1101,  0.0890,
#          -0.1471,  0.0498]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1909, grad_fn=<NllLossBackward>)
# tensor([[ 0.0014,  0.0134,  0.1038,  0.0174,  0.0263,  0.0322, -0.1157,  0.0998,
#          -0.1550,  0.0215]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2838, grad_fn=<NllLossBackward>)
# tensor([[-8.4646e-03,  1.1824e-02,  1.1890e-01, -2.1264e-02, -1.3661e-04,
#           2.6782e-02, -1.1428e-01,  5.1319e-02, -1.4486e-01,  2.0252e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2874, grad_fn=<NllLossBackward>)
# tensor([[ 0.0074,  0.0132,  0.1093,  0.0058,  0.0236,  0.0307, -0.1145,  0.0959,
#          -0.1568,  0.0306]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2795, grad_fn=<NllLossBackward>)
# tensor([[-0.0145,  0.0121,  0.1329,  0.0104, -0.0093,  0.0512, -0.1265,  0.0871,
#          -0.1563,  0.0333]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2569, grad_fn=<NllLossBackward>)
# tensor([[ 0.0062,  0.0113,  0.1322,  0.0154,  0.0045,  0.0420, -0.1264,  0.0862,
#          -0.1454,  0.0377]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3076, grad_fn=<NllLossBackward>)
# tensor([[ 0.0052, -0.0003,  0.1122, -0.0058,  0.0305, -0.0089, -0.1093,  0.0945,
#          -0.1407,  0.0294]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4153, grad_fn=<NllLossBackward>)
# tensor([[ 0.0031, -0.0047,  0.1045, -0.0221,  0.0253,  0.0003, -0.1129,  0.0909,
#          -0.1623,  0.0254]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.3000, grad_fn=<NllLossBackward>)
# tensor([[-0.0069, -0.0040,  0.1040,  0.0178,  0.0272,  0.0082, -0.1104,  0.0937,
#          -0.1205,  0.0187]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4181, grad_fn=<NllLossBackward>)
# tensor([[ 0.0021,  0.0130,  0.1075,  0.0033,  0.0187,  0.0124, -0.1214,  0.0610,
#          -0.1303,  0.0176]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3012, grad_fn=<NllLossBackward>)
# tensor([[-0.0122,  0.0085,  0.1028, -0.0167,  0.0008,  0.0359, -0.1168,  0.0894,
#          -0.1701,  0.0185]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2812, grad_fn=<NllLossBackward>)
# tensor([[-0.0081,  0.0095,  0.1369,  0.0193,  0.0107,  0.0291, -0.1194,  0.0754,
#          -0.1400,  0.0190]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2895, grad_fn=<NllLossBackward>)
# tensor([[-0.0057,  0.0101,  0.1226,  0.0137,  0.0018,  0.0267, -0.1258,  0.0768,
#          -0.1456,  0.0308]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2753, grad_fn=<NllLossBackward>)
# tensor([[ 0.0061,  0.0134,  0.1132,  0.0121,  0.0321,  0.0263, -0.1195,  0.0776,
#          -0.1354,  0.0286]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2331, grad_fn=<NllLossBackward>)
# tensor([[ 0.0007,  0.0064,  0.1065,  0.0052,  0.0319,  0.0120, -0.1121,  0.0807,
#          -0.1431,  0.0219]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4183, grad_fn=<NllLossBackward>)
# tensor([[-0.0009, -0.0054,  0.0959, -0.0183,  0.0133,  0.0149, -0.1120,  0.0836,
#          -0.1608,  0.0391]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2612, grad_fn=<NllLossBackward>)
# tensor([[ 0.0106,  0.0153,  0.1029,  0.0016,  0.0283,  0.0120, -0.1187,  0.0838,
#          -0.1424,  0.0356]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4506, grad_fn=<NllLossBackward>)
# tensor([[-0.0281,  0.0026,  0.1324, -0.0040,  0.0175,  0.0183, -0.1044,  0.0807,
#          -0.1430,  0.0409]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3349, grad_fn=<NllLossBackward>)
# tensor([[-0.0042, -0.0160,  0.1197, -0.0096,  0.0101,  0.0084, -0.1073,  0.0667,
#          -0.1432,  0.0345]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3107, grad_fn=<NllLossBackward>)
# tensor([[-0.0042, -0.0086,  0.1088, -0.0122, -0.0054,  0.0329, -0.1015,  0.0708,
#          -0.1659,  0.0341]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4661, grad_fn=<NllLossBackward>)
# tensor([[ 0.0080,  0.0072,  0.1055,  0.0045,  0.0156,  0.0275, -0.1122,  0.0812,
#          -0.1495,  0.0254]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4561, grad_fn=<NllLossBackward>)
# tensor([[-0.0029,  0.0139,  0.1413, -0.0062, -0.0203,  0.0557, -0.1341,  0.0945,
#          -0.1435,  0.0434]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2159, grad_fn=<NllLossBackward>)
# tensor([[-0.0088, -0.0125,  0.1483,  0.0037,  0.0214,  0.0101, -0.1118,  0.0896,
#          -0.1264,  0.0418]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2215, grad_fn=<NllLossBackward>)
# tensor([[-0.0058,  0.0104,  0.1061,  0.0112,  0.0096,  0.0380, -0.1211,  0.0753,
#          -0.1463,  0.0251]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2959, grad_fn=<NllLossBackward>)
# tensor([[-0.0026,  0.0094,  0.1182,  0.0091,  0.0205,  0.0376, -0.1075,  0.0894,
#          -0.1499,  0.0272]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4181, grad_fn=<NllLossBackward>)
# tensor([[-0.0125,  0.0188,  0.1185,  0.0233,  0.0076,  0.0546, -0.1183,  0.0884,
#          -0.1574,  0.0188]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2216, grad_fn=<NllLossBackward>)
# tensor([[-0.0053,  0.0199,  0.1281,  0.0241,  0.0198,  0.0230, -0.1160,  0.0969,
#          -0.1499,  0.0108]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2868, grad_fn=<NllLossBackward>)
# tensor([[-0.0168, -0.0048,  0.1397, -0.0074,  0.0111,  0.0142, -0.1209,  0.0852,
#          -0.1437,  0.0588]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4283, grad_fn=<NllLossBackward>)
# tensor([[ 2.2273e-02, -2.9052e-05,  8.6955e-02,  3.3441e-04,  1.0208e-02,
#           6.0358e-03, -1.2607e-01,  7.3455e-02, -1.5052e-01,  2.0879e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2992, grad_fn=<NllLossBackward>)
# tensor([[-0.0063, -0.0005,  0.1061,  0.0013,  0.0178,  0.0161, -0.1069,  0.0904,
#          -0.1476,  0.0222]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4114, grad_fn=<NllLossBackward>)
# tensor([[-1.2377e-04,  9.4515e-03,  1.1926e-01,  5.7490e-03,  1.3006e-02,
#           8.3818e-03, -1.1245e-01,  8.4512e-02, -1.3324e-01,  3.9768e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1894, grad_fn=<NllLossBackward>)
# tensor([[ 0.0136,  0.0061,  0.1119,  0.0014,  0.0231,  0.0263, -0.1225,  0.0870,
#          -0.1402,  0.0296]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3029, grad_fn=<NllLossBackward>)
# tensor([[-0.0204,  0.0145,  0.1154,  0.0197,  0.0025,  0.0573, -0.1130,  0.0872,
#          -0.1662,  0.0228]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1924, grad_fn=<NllLossBackward>)
# tensor([[ 0.0052, -0.0048,  0.1075, -0.0030,  0.0147,  0.0048, -0.1160,  0.0764,
#          -0.1385,  0.0149]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3042, grad_fn=<NllLossBackward>)
# tensor([[ 0.0043, -0.0060,  0.0912, -0.0132,  0.0071,  0.0228, -0.1079,  0.0693,
#          -0.1621,  0.0394]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2304, grad_fn=<NllLossBackward>)
# tensor([[ 0.0024,  0.0076,  0.0982,  0.0082,  0.0073,  0.0418, -0.1152,  0.0741,
#          -0.1507,  0.0185]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2062, grad_fn=<NllLossBackward>)
# tensor([[ 0.0106,  0.0021,  0.1146,  0.0129,  0.0251,  0.0150, -0.1192,  0.0926,
#          -0.1335,  0.0309]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4296, grad_fn=<NllLossBackward>)
# tensor([[ 0.0087,  0.0117,  0.1061,  0.0015,  0.0120,  0.0437, -0.1273,  0.0756,
#          -0.1505,  0.0207]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4562, grad_fn=<NllLossBackward>)
# tensor([[-0.0050,  0.0068,  0.1155,  0.0111,  0.0107,  0.0280, -0.1178,  0.0794,
#          -0.1402,  0.0210]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4464, grad_fn=<NllLossBackward>)
# tensor([[ 0.0194,  0.0077,  0.0858,  0.0065,  0.0182,  0.0206, -0.1245,  0.0817,
#          -0.1443,  0.0174]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.2846, grad_fn=<NllLossBackward>)
# tensor([[-0.0074,  0.0057,  0.1092,  0.0211,  0.0297,  0.0197, -0.1158,  0.0789,
#          -0.1409,  0.0154]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1976, grad_fn=<NllLossBackward>)
# tensor([[ 0.0014,  0.0054,  0.1119, -0.0007,  0.0031,  0.0372, -0.1129,  0.0845,
#          -0.1534,  0.0310]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2752, grad_fn=<NllLossBackward>)
# tensor([[-0.0004,  0.0245,  0.1273,  0.0291,  0.0031,  0.0341, -0.1229,  0.0820,
#          -0.1386,  0.0263]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2829, grad_fn=<NllLossBackward>)
# tensor([[-0.0142,  0.0119,  0.1286,  0.0048,  0.0221,  0.0113, -0.1244,  0.0748,
#          -0.1489,  0.0309]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3005, grad_fn=<NllLossBackward>)
# tensor([[ 0.0134,  0.0189,  0.1095,  0.0186,  0.0006,  0.0691, -0.1338,  0.0921,
#          -0.1482,  0.0157]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4596, grad_fn=<NllLossBackward>)
# tensor([[-0.0084,  0.0028,  0.0976,  0.0094,  0.0117,  0.0393, -0.1085,  0.0751,
#          -0.1628,  0.0078]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4645, grad_fn=<NllLossBackward>)
# tensor([[-0.0257,  0.0118,  0.1387, -0.0174,  0.0296,  0.0065, -0.1175,  0.0916,
#          -0.1440,  0.0419]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2956, grad_fn=<NllLossBackward>)
# tensor([[ 0.0022,  0.0062,  0.1159,  0.0216,  0.0233,  0.0310, -0.1134,  0.1052,
#          -0.1550,  0.0153]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3047, grad_fn=<NllLossBackward>)
# tensor([[-0.0071,  0.0137,  0.1179,  0.0210,  0.0005,  0.0604, -0.1114,  0.0713,
#          -0.1625,  0.0206]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2368, grad_fn=<NllLossBackward>)
# tensor([[-0.0070, -0.0007,  0.0908, -0.0017, -0.0015,  0.0470, -0.1151,  0.0906,
#          -0.1648,  0.0094]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2094, grad_fn=<NllLossBackward>)
# tensor([[ 0.0042,  0.0019,  0.0947, -0.0077,  0.0322,  0.0096, -0.1023,  0.0935,
#          -0.1593,  0.0081]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2932, grad_fn=<NllLossBackward>)
# tensor([[-0.0009, -0.0085,  0.1216, -0.0205, -0.0075,  0.0084, -0.1152,  0.0778,
#          -0.1416,  0.0360]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1787, grad_fn=<NllLossBackward>)
# tensor([[ 0.0048,  0.0179,  0.0994, -0.0010, -0.0035,  0.0601, -0.1252,  0.0783,
#          -0.1627,  0.0226]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2264, grad_fn=<NllLossBackward>)
# tensor([[ 0.0074,  0.0162,  0.0986,  0.0044, -0.0060,  0.0381, -0.1269,  0.0816,
#          -0.1559,  0.0243]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4596, grad_fn=<NllLossBackward>)
# tensor([[ 0.0047,  0.0119,  0.1237,  0.0175,  0.0206,  0.0276, -0.1183,  0.0889,
#          -0.1333,  0.0206]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2912, grad_fn=<NllLossBackward>)
# tensor([[-0.0022,  0.0081,  0.1228,  0.0135,  0.0121,  0.0405, -0.1178,  0.0801,
#          -0.1540,  0.0197]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3101, grad_fn=<NllLossBackward>)
# tensor([[-0.0014,  0.0047,  0.1074, -0.0030,  0.0293,  0.0118, -0.1129,  0.0835,
#          -0.1439,  0.0230]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3080, grad_fn=<NllLossBackward>)
# tensor([[-0.0097,  0.0156,  0.1119,  0.0077, -0.0023,  0.0582, -0.1151,  0.0780,
#          -0.1686,  0.0135]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4732, grad_fn=<NllLossBackward>)
# tensor([[ 1.5869e-04,  8.3797e-03,  9.1588e-02, -2.2943e-03,  3.2361e-02,
#           1.0690e-02, -1.1261e-01,  8.6552e-02, -1.6154e-01,  7.4830e-03]],
#        grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4140, grad_fn=<NllLossBackward>)
# tensor([[ 0.0011,  0.0026,  0.1085,  0.0028,  0.0245,  0.0057, -0.1127,  0.0797,
#          -0.1368,  0.0226]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2804, grad_fn=<NllLossBackward>)
# tensor([[ 0.0016,  0.0201,  0.1158,  0.0209,  0.0153,  0.0470, -0.1191,  0.0930,
#          -0.1511,  0.0194]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4310, grad_fn=<NllLossBackward>)
# tensor([[-0.0040,  0.0025,  0.1181, -0.0009,  0.0183,  0.0184, -0.1172,  0.0819,
#          -0.1427,  0.0281]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4228, grad_fn=<NllLossBackward>)
# tensor([[-0.0075,  0.0064,  0.1107,  0.0147,  0.0139,  0.0400, -0.1114,  0.0836,
#          -0.1476,  0.0181]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3149, grad_fn=<NllLossBackward>)
# tensor([[ 0.0010,  0.0238,  0.1145,  0.0192,  0.0161,  0.0715, -0.1164,  0.0960,
#          -0.1803,  0.0141]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3111, grad_fn=<NllLossBackward>)
# tensor([[-0.0005,  0.0282,  0.1138,  0.0139,  0.0245,  0.0297, -0.1233,  0.0726,
#          -0.1524, -0.0035]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2332, grad_fn=<NllLossBackward>)
# tensor([[-0.0153,  0.0071,  0.1033,  0.0084,  0.0157,  0.0407, -0.1085,  0.0943,
#          -0.1519,  0.0250]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2915, grad_fn=<NllLossBackward>)
# tensor([[-0.0074,  0.0176,  0.1215,  0.0186,  0.0180,  0.0422, -0.1162,  0.0927,
#          -0.1475,  0.0302]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2704, grad_fn=<NllLossBackward>)
# tensor([[-0.0057, -0.0036,  0.1472, -0.0035,  0.0065,  0.0081, -0.1233,  0.0812,
#          -0.1265,  0.0580]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4328, grad_fn=<NllLossBackward>)
# tensor([[ 0.0041,  0.0009,  0.0981, -0.0189,  0.0068,  0.0206, -0.1112,  0.0888,
#          -0.1576,  0.0441]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3219, grad_fn=<NllLossBackward>)
# tensor([[-0.0124,  0.0114,  0.1407,  0.0076,  0.0137,  0.0271, -0.1168,  0.0931,
#          -0.1482,  0.0366]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2998, grad_fn=<NllLossBackward>)
# tensor([[ 0.0332,  0.0181,  0.1066,  0.0131,  0.0143,  0.0496, -0.1371,  0.0919,
#          -0.1537,  0.0311]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2944, grad_fn=<NllLossBackward>)
# tensor([[-0.0115,  0.0009,  0.1179,  0.0067,  0.0164,  0.0195, -0.1076,  0.0889,
#          -0.1346,  0.0375]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3019, grad_fn=<NllLossBackward>)
# tensor([[-0.0081,  0.0032,  0.1153, -0.0007,  0.0345,  0.0041, -0.1136,  0.0807,
#          -0.1366,  0.0234]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4190, grad_fn=<NllLossBackward>)
# tensor([[-0.0292, -0.0119,  0.1426,  0.0021, -0.0137,  0.0499, -0.1180,  0.0562,
#          -0.1391,  0.0638]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4452, grad_fn=<NllLossBackward>)
# tensor([[-0.0127,  0.0006,  0.1685,  0.0081, -0.0349,  0.0699, -0.1056,  0.0872,
#          -0.1581,  0.0622]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2280, grad_fn=<NllLossBackward>)
# tensor([[ 0.0116,  0.0193,  0.1075, -0.0020,  0.0302,  0.0244, -0.1283,  0.0925,
#          -0.1531,  0.0328]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2790, grad_fn=<NllLossBackward>)
# tensor([[-0.0382,  0.0227,  0.1325,  0.0299, -0.0025,  0.0733, -0.1094,  0.1024,
#          -0.1780,  0.0165]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3496, grad_fn=<NllLossBackward>)
# tensor([[ 0.0054,  0.0051,  0.0870, -0.0022,  0.0261,  0.0296, -0.1139,  0.0842,
#          -0.1660,  0.0159]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4163, grad_fn=<NllLossBackward>)
# tensor([[-0.0026,  0.0210,  0.0973,  0.0053,  0.0291,  0.0251, -0.1177,  0.0798,
#          -0.1475,  0.0155]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2084, grad_fn=<NllLossBackward>)
# tensor([[ 0.0053,  0.0165,  0.0934, -0.0116,  0.0349,  0.0119, -0.1208,  0.0858,
#          -0.1508,  0.0092]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2861, grad_fn=<NllLossBackward>)
# tensor([[ 0.0150,  0.0099,  0.1054,  0.0116,  0.0274,  0.0284, -0.1286,  0.1102,
#          -0.1466,  0.0280]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3002, grad_fn=<NllLossBackward>)
# tensor([[-0.0027,  0.0217,  0.1138,  0.0361,  0.0189,  0.0455, -0.1179,  0.1114,
#          -0.1408,  0.0130]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3182, grad_fn=<NllLossBackward>)
# tensor([[-0.0036, -0.0014,  0.1111, -0.0024,  0.0216,  0.0039, -0.1016,  0.0750,
#          -0.1502,  0.0158]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2803, grad_fn=<NllLossBackward>)
# tensor([[ 0.0031, -0.0084,  0.1232, -0.0018,  0.0314, -0.0195, -0.1146,  0.0876,
#          -0.1276,  0.0368]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1831, grad_fn=<NllLossBackward>)
# tensor([[-0.0056,  0.0059,  0.1383,  0.0165, -0.0081,  0.0448, -0.1175,  0.0705,
#          -0.1328,  0.0252]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2387, grad_fn=<NllLossBackward>)
# tensor([[ 0.0026,  0.0005,  0.0937, -0.0019,  0.0090,  0.0319, -0.1123,  0.0653,
#          -0.1471,  0.0258]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4488, grad_fn=<NllLossBackward>)
# tensor([[-0.0285,  0.0028,  0.1268,  0.0129,  0.0251,  0.0232, -0.1107,  0.0954,
#          -0.1398,  0.0344]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2968, grad_fn=<NllLossBackward>)
# tensor([[ 0.0009, -0.0043,  0.1273,  0.0030,  0.0228,  0.0128, -0.1047,  0.0877,
#          -0.1454,  0.0271]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3125, grad_fn=<NllLossBackward>)
# tensor([[ 0.0070,  0.0183,  0.1003,  0.0281,  0.0350,  0.0399, -0.1180,  0.0977,
#          -0.1500, -0.0054]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2105, grad_fn=<NllLossBackward>)
# tensor([[ 0.0028,  0.0103,  0.0925,  0.0214,  0.0168,  0.0300, -0.1217,  0.0852,
#          -0.1421,  0.0157]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4483, grad_fn=<NllLossBackward>)
# tensor([[-0.0072,  0.0038,  0.1098,  0.0016,  0.0202,  0.0188, -0.1197,  0.0758,
#          -0.1420,  0.0248]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3110, grad_fn=<NllLossBackward>)
# tensor([[-0.0104, -0.0065,  0.1154,  0.0004,  0.0011,  0.0260, -0.0940,  0.0810,
#          -0.1584,  0.0346]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4626, grad_fn=<NllLossBackward>)
# tensor([[-2.0302e-03,  4.7298e-05,  1.3796e-01,  4.3119e-03, -8.8507e-03,
#           2.8429e-02, -1.2729e-01,  7.5123e-02, -1.3245e-01,  5.2897e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3042, grad_fn=<NllLossBackward>)
# tensor([[-0.0192,  0.0064,  0.1074,  0.0083,  0.0305,  0.0323, -0.1051,  0.1041,
#          -0.1550,  0.0103]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2752, grad_fn=<NllLossBackward>)
# tensor([[-0.0042,  0.0113,  0.0978,  0.0015,  0.0089,  0.0270, -0.1133,  0.0730,
#          -0.1562,  0.0227]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2043, grad_fn=<NllLossBackward>)
# tensor([[ 0.0017,  0.0232,  0.1070,  0.0112,  0.0202,  0.0515, -0.1355,  0.0898,
#          -0.1425,  0.0170]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2898, grad_fn=<NllLossBackward>)
# tensor([[-0.0049,  0.0059,  0.1085,  0.0003, -0.0018,  0.0544, -0.1119,  0.0846,
#          -0.1889,  0.0274]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2975, grad_fn=<NllLossBackward>)
# tensor([[ 0.0066,  0.0072,  0.0938,  0.0004,  0.0191,  0.0114, -0.1118,  0.0889,
#          -0.1607,  0.0212]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4637, grad_fn=<NllLossBackward>)
# tensor([[ 0.0043,  0.0190,  0.1080,  0.0058,  0.0235,  0.0225, -0.1175,  0.1044,
#          -0.1622,  0.0079]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2994, grad_fn=<NllLossBackward>)
# tensor([[-0.0185, -0.0035,  0.1142,  0.0095,  0.0079,  0.0417, -0.1036,  0.0880,
#          -0.1633,  0.0068]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3070, grad_fn=<NllLossBackward>)
# tensor([[-0.0055,  0.0041,  0.1102, -0.0018,  0.0082,  0.0396, -0.1174,  0.0892,
#          -0.1509,  0.0447]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1974, grad_fn=<NllLossBackward>)
# tensor([[ 0.0097,  0.0087,  0.0940, -0.0202,  0.0232,  0.0086, -0.1142,  0.0800,
#          -0.1555,  0.0278]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2737, grad_fn=<NllLossBackward>)
# tensor([[ 0.0120,  0.0203,  0.1069,  0.0199,  0.0088,  0.0394, -0.1181,  0.0813,
#          -0.1580,  0.0208]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2275, grad_fn=<NllLossBackward>)
# tensor([[ 0.0023,  0.0050,  0.1161,  0.0039,  0.0258,  0.0207, -0.1234,  0.0798,
#          -0.1426,  0.0328]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1913, grad_fn=<NllLossBackward>)
# tensor([[ 0.0011,  0.0099,  0.1127, -0.0048,  0.0241,  0.0340, -0.1126,  0.0706,
#          -0.1499,  0.0230]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2831, grad_fn=<NllLossBackward>)
# tensor([[-0.0126,  0.0105,  0.1120,  0.0082,  0.0149,  0.0349, -0.1083,  0.0931,
#          -0.1601,  0.0239]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4156, grad_fn=<NllLossBackward>)
# tensor([[-0.0275,  0.0005,  0.1354, -0.0145, -0.0185,  0.0254, -0.1192,  0.0700,
#          -0.1675,  0.0552]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2746, grad_fn=<NllLossBackward>)
# tensor([[-0.0074,  0.0202,  0.0975,  0.0260,  0.0087,  0.0571, -0.0954,  0.0805,
#          -0.1695,  0.0066]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4032, grad_fn=<NllLossBackward>)
# tensor([[ 0.0039,  0.0071,  0.1283,  0.0069,  0.0050,  0.0349, -0.1239,  0.0791,
#          -0.1303,  0.0296]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3026, grad_fn=<NllLossBackward>)
# tensor([[-0.0068,  0.0045,  0.1139, -0.0057, -0.0048,  0.0522, -0.1053,  0.0894,
#          -0.1529,  0.0588]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4629, grad_fn=<NllLossBackward>)
# tensor([[-0.0075,  0.0049,  0.0984,  0.0074, -0.0083,  0.0476, -0.1102,  0.0899,
#          -0.1614,  0.0129]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2130, grad_fn=<NllLossBackward>)
# tensor([[-0.0018, -0.0024,  0.1207,  0.0021,  0.0254,  0.0057, -0.1110,  0.0913,
#          -0.1394,  0.0432]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4197, grad_fn=<NllLossBackward>)
# tensor([[ 0.0171,  0.0067,  0.1319,  0.0043, -0.0150,  0.0299, -0.1174,  0.0565,
#          -0.1446,  0.0245]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1729, grad_fn=<NllLossBackward>)
# tensor([[-0.0022, -0.0018,  0.1536,  0.0195, -0.0299,  0.0394, -0.1121,  0.0860,
#          -0.1263,  0.0545]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2744, grad_fn=<NllLossBackward>)
# tensor([[-0.0057, -0.0003,  0.1407, -0.0131, -0.0154,  0.0231, -0.1016,  0.0855,
#          -0.1613,  0.0520]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1656, grad_fn=<NllLossBackward>)
# tensor([[ 0.0003,  0.0056,  0.1117, -0.0020, -0.0005,  0.0265, -0.1266,  0.0767,
#          -0.1342,  0.0331]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4385, grad_fn=<NllLossBackward>)
# tensor([[ 0.0162, -0.0005,  0.1174, -0.0036,  0.0022,  0.0188, -0.1048,  0.0945,
#          -0.1576,  0.0644]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2460, grad_fn=<NllLossBackward>)
# tensor([[-3.4129e-03,  3.7188e-03,  1.0794e-01,  1.6114e-05,  3.0633e-02,
#           1.1744e-02, -1.1822e-01,  8.6474e-02, -1.4394e-01,  2.7064e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4237, grad_fn=<NllLossBackward>)
# tensor([[-0.0137,  0.0070,  0.1100,  0.0116,  0.0034,  0.0509, -0.1164,  0.0755,
#          -0.1532,  0.0034]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3170, grad_fn=<NllLossBackward>)
# tensor([[-0.0156,  0.0069,  0.1081,  0.0094,  0.0321,  0.0196, -0.1114,  0.1034,
#          -0.1471,  0.0075]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3224, grad_fn=<NllLossBackward>)
# tensor([[ 0.0014,  0.0056,  0.1254,  0.0166,  0.0075,  0.0277, -0.1107,  0.0893,
#          -0.1406,  0.0274]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2827, grad_fn=<NllLossBackward>)
# tensor([[-0.0257,  0.0150,  0.1164,  0.0301,  0.0077,  0.0713, -0.1084,  0.0876,
#          -0.1669,  0.0123]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1935, grad_fn=<NllLossBackward>)
# tensor([[ 0.0108,  0.0159,  0.1066, -0.0199,  0.0140,  0.0241, -0.1259,  0.0726,
#          -0.1463,  0.0362]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2679, grad_fn=<NllLossBackward>)
# tensor([[-0.0162,  0.0071,  0.1143,  0.0047,  0.0248,  0.0191, -0.1111,  0.0835,
#          -0.1540,  0.0265]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2862, grad_fn=<NllLossBackward>)
# tensor([[ 0.0065,  0.0115,  0.0985,  0.0096,  0.0264,  0.0122, -0.1221,  0.0802,
#          -0.1380,  0.0144]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2786, grad_fn=<NllLossBackward>)
# tensor([[-0.0148,  0.0065,  0.1110,  0.0050,  0.0132,  0.0226, -0.1204,  0.1005,
#          -0.1492,  0.0008]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1920, grad_fn=<NllLossBackward>)
# tensor([[-0.0120, -0.0086,  0.1527,  0.0146,  0.0229,  0.0178, -0.1149,  0.0733,
#          -0.1349,  0.0459]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3200, grad_fn=<NllLossBackward>)
# tensor([[ 0.0052,  0.0107,  0.1074,  0.0008,  0.0206,  0.0220, -0.1190,  0.0991,
#          -0.1457,  0.0180]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4264, grad_fn=<NllLossBackward>)
# tensor([[ 0.0032,  0.0074,  0.1162,  0.0043,  0.0203,  0.0164, -0.1195,  0.0875,
#          -0.1349,  0.0306]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4279, grad_fn=<NllLossBackward>)
# tensor([[ 0.0102,  0.0018,  0.1193,  0.0020, -0.0206,  0.0465, -0.1197,  0.0716,
#          -0.1420,  0.0352]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4478, grad_fn=<NllLossBackward>)
# tensor([[ 0.0132,  0.0014,  0.0826, -0.0007,  0.0234,  0.0073, -0.1107,  0.0771,
#          -0.1357,  0.0096]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2781, grad_fn=<NllLossBackward>)
# tensor([[-0.0083, -0.0024,  0.1063,  0.0032,  0.0005,  0.0438, -0.1071,  0.0705,
#          -0.1558,  0.0297]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4591, grad_fn=<NllLossBackward>)
# tensor([[-0.0008,  0.0076,  0.1100,  0.0046,  0.0264,  0.0078, -0.1165,  0.0831,
#          -0.1403,  0.0243]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2795, grad_fn=<NllLossBackward>)
# tensor([[-0.0112,  0.0088,  0.1131,  0.0025,  0.0201,  0.0370, -0.0998,  0.0822,
#          -0.1729,  0.0156]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2681, grad_fn=<NllLossBackward>)
# tensor([[ 0.0100,  0.0047,  0.0929, -0.0111,  0.0142,  0.0185, -0.1215,  0.0645,
#          -0.1495,  0.0228]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.2897, grad_fn=<NllLossBackward>)
# tensor([[ 0.0070,  0.0254,  0.1298,  0.0076, -0.0042,  0.0538, -0.1247,  0.0835,
#          -0.1508,  0.0314]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2804, grad_fn=<NllLossBackward>)
# tensor([[ 0.0167,  0.0175,  0.0872,  0.0146,  0.0145,  0.0221, -0.1250,  0.0877,
#          -0.1617,  0.0044]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2988, grad_fn=<NllLossBackward>)
# tensor([[-0.0058, -0.0011,  0.1038,  0.0054,  0.0237,  0.0268, -0.1101,  0.0843,
#          -0.1390,  0.0108]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2942, grad_fn=<NllLossBackward>)
# tensor([[ 0.0009,  0.0349,  0.1237,  0.0152,  0.0240,  0.0239, -0.1204,  0.0892,
#          -0.1523,  0.0278]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4647, grad_fn=<NllLossBackward>)
# tensor([[ 0.0131,  0.0145,  0.1183,  0.0110,  0.0157,  0.0229, -0.1194,  0.0982,
#          -0.1562,  0.0070]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.3012, grad_fn=<NllLossBackward>)
# tensor([[ 0.0143, -0.0008,  0.0758, -0.0253,  0.0214,  0.0053, -0.1255,  0.0797,
#          -0.1541,  0.0171]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2789, grad_fn=<NllLossBackward>)
# tensor([[-0.0135,  0.0065,  0.1134,  0.0100,  0.0199,  0.0198, -0.1135,  0.0846,
#          -0.1440,  0.0115]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor([[ 0.0026,  0.0220,  0.1099,  0.0157,  0.0308,  0.0265, -0.1186,  0.1032,
#          -0.1575,  0.0238]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2084, grad_fn=<NllLossBackward>)
# tensor([[-0.0138,  0.0128,  0.1169,  0.0068,  0.0222,  0.0278, -0.1028,  0.1024,
#          -0.1642,  0.0214]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2809, grad_fn=<NllLossBackward>)
# tensor([[ 0.0004,  0.0148,  0.0988,  0.0098,  0.0183,  0.0288, -0.1191,  0.0951,
#          -0.1508,  0.0045]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3050, grad_fn=<NllLossBackward>)
# tensor([[ 0.0005,  0.0132,  0.1229,  0.0269, -0.0004,  0.0639, -0.1246,  0.0847,
#          -0.1434,  0.0155]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3111, grad_fn=<NllLossBackward>)
# tensor([[ 0.0088,  0.0179,  0.1049,  0.0134, -0.0007,  0.0605, -0.1221,  0.0995,
#          -0.1587,  0.0182]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2495, grad_fn=<NllLossBackward>)
# tensor([[ 0.0077,  0.0124,  0.1109, -0.0046,  0.0045,  0.0401, -0.1126,  0.0769,
#          -0.1577,  0.0435]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1967, grad_fn=<NllLossBackward>)
# tensor([[-0.0056,  0.0088,  0.1079,  0.0115,  0.0224,  0.0213, -0.1123,  0.0829,
#          -0.1445,  0.0155]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1981, grad_fn=<NllLossBackward>)
# tensor([[-0.0057,  0.0042,  0.0842, -0.0022,  0.0085,  0.0371, -0.1205,  0.0853,
#          -0.1564,  0.0046]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3014, grad_fn=<NllLossBackward>)
# tensor([[-0.0096,  0.0080,  0.1204,  0.0192,  0.0051,  0.0413, -0.1184,  0.0733,
#          -0.1427,  0.0179]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4496, grad_fn=<NllLossBackward>)
# tensor([[-0.0002,  0.0010,  0.1215, -0.0013,  0.0350, -0.0047, -0.1148,  0.0894,
#          -0.1361,  0.0410]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4233, grad_fn=<NllLossBackward>)
# tensor([[-0.0062,  0.0009,  0.0943,  0.0005,  0.0231,  0.0169, -0.1152,  0.0840,
#          -0.1404,  0.0154]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3019, grad_fn=<NllLossBackward>)
# tensor([[ 0.0063,  0.0483,  0.1137,  0.0304,  0.0176,  0.0794, -0.1193,  0.1285,
#          -0.1846,  0.0128]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3025, grad_fn=<NllLossBackward>)
# tensor([[-0.0172, -0.0146,  0.1153,  0.0126, -0.0043,  0.0257, -0.0917,  0.0736,
#          -0.1532,  0.0049]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3174, grad_fn=<NllLossBackward>)
# tensor([[ 0.0224,  0.0190,  0.1187,  0.0088,  0.0024,  0.0474, -0.1265,  0.0814,
#          -0.1511,  0.0346]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2640, grad_fn=<NllLossBackward>)
# tensor([[-0.0070, -0.0047,  0.1267, -0.0060, -0.0011,  0.0246, -0.1195,  0.0701,
#          -0.1486,  0.0395]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4516, grad_fn=<NllLossBackward>)
# tensor([[ 0.0012,  0.0226,  0.1153,  0.0118,  0.0190,  0.0275, -0.1290,  0.0943,
#          -0.1403,  0.0347]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3101, grad_fn=<NllLossBackward>)
# tensor([[-0.0133,  0.0067,  0.1358,  0.0160,  0.0094,  0.0276, -0.1116,  0.0836,
#          -0.1502,  0.0323]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3026, grad_fn=<NllLossBackward>)
# tensor([[-0.0046,  0.0061,  0.1023,  0.0004,  0.0291,  0.0090, -0.1105,  0.0953,
#          -0.1524,  0.0239]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2099, grad_fn=<NllLossBackward>)
# tensor([[-0.0054,  0.0047,  0.1259,  0.0108,  0.0209,  0.0147, -0.1146,  0.0847,
#          -0.1422,  0.0161]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1811, grad_fn=<NllLossBackward>)
# tensor([[-0.0225, -0.0121,  0.1326, -0.0056, -0.0160,  0.0389, -0.0849,  0.0820,
#          -0.1748,  0.0303]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4774, grad_fn=<NllLossBackward>)
# tensor([[-0.0095,  0.0144,  0.1103,  0.0160, -0.0093,  0.0828, -0.1195,  0.0772,
#          -0.1649,  0.0265]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4732, grad_fn=<NllLossBackward>)
# tensor([[-0.0178,  0.0112,  0.1215,  0.0183,  0.0090,  0.0064, -0.1142,  0.1035,
#          -0.1438, -0.0191]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.1996, grad_fn=<NllLossBackward>)
# tensor([[-0.0134,  0.0121,  0.1305,  0.0182,  0.0051,  0.0585, -0.1183,  0.0825,
#          -0.1465,  0.0302]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4582, grad_fn=<NllLossBackward>)
# tensor([[-0.0093, -0.0084,  0.0994, -0.0100,  0.0191,  0.0103, -0.0990,  0.0902,
#          -0.1656,  0.0358]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2913, grad_fn=<NllLossBackward>)
# tensor([[ 0.0058,  0.0023,  0.0896, -0.0155,  0.0123,  0.0182, -0.1217,  0.0668,
#          -0.1624,  0.0093]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2934, grad_fn=<NllLossBackward>)
# tensor([[ 0.0043,  0.0086,  0.0982,  0.0164,  0.0163,  0.0247, -0.1188,  0.0841,
#          -0.1437,  0.0111]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4490, grad_fn=<NllLossBackward>)
# tensor([[-6.7763e-03,  1.2904e-02,  1.2837e-01,  3.0581e-03,  3.5084e-02,
#          -1.2609e-04, -1.1674e-01,  1.0365e-01, -1.3626e-01,  2.6572e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2069, grad_fn=<NllLossBackward>)
# tensor([[ 0.0025, -0.0068,  0.1077,  0.0140,  0.0263,  0.0101, -0.1098,  0.0756,
#          -0.1278,  0.0261]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3135, grad_fn=<NllLossBackward>)
# tensor([[-0.0004,  0.0154,  0.1080,  0.0127,  0.0023,  0.0578, -0.1289,  0.0689,
#          -0.1553,  0.0287]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2938, grad_fn=<NllLossBackward>)
# tensor([[-0.0118, -0.0091,  0.1252, -0.0027,  0.0106,  0.0092, -0.1144,  0.0774,
#          -0.1390,  0.0405]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3157, grad_fn=<NllLossBackward>)
# tensor([[-0.0153,  0.0135,  0.1157,  0.0144,  0.0069,  0.0508, -0.1286,  0.0910,
#          -0.1583,  0.0216]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2562, grad_fn=<NllLossBackward>)
# tensor([[-0.0047,  0.0146,  0.1190,  0.0148,  0.0142,  0.0421, -0.1199,  0.0927,
#          -0.1615,  0.0402]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2184, grad_fn=<NllLossBackward>)
# tensor([[-0.0016,  0.0176,  0.1085, -0.0025,  0.0061,  0.0387, -0.1153,  0.0789,
#          -0.1573,  0.0226]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2824, grad_fn=<NllLossBackward>)
# tensor([[-0.0015,  0.0150,  0.1029,  0.0068,  0.0386,  0.0121, -0.1041,  0.0907,
#          -0.1570,  0.0237]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2174, grad_fn=<NllLossBackward>)
# tensor([[ 0.0075,  0.0089,  0.0941, -0.0167,  0.0233,  0.0234, -0.1259,  0.0953,
#          -0.1597,  0.0305]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2804, grad_fn=<NllLossBackward>)
# tensor([[-0.0440,  0.0026,  0.1369,  0.0233, -0.0282,  0.0875, -0.1009,  0.1036,
#          -0.1833,  0.0285]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2219, grad_fn=<NllLossBackward>)
# tensor([[-0.0084,  0.0048,  0.1020, -0.0041,  0.0225,  0.0206, -0.1005,  0.0830,
#          -0.1748,  0.0183]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2835, grad_fn=<NllLossBackward>)
# tensor([[-0.0123, -0.0095,  0.1092, -0.0119,  0.0030,  0.0285, -0.0949,  0.0699,
#          -0.1626,  0.0299]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4628, grad_fn=<NllLossBackward>)
# tensor([[-0.0223,  0.0127,  0.1024,  0.0181,  0.0018,  0.0670, -0.0983,  0.0793,
#          -0.1794,  0.0197]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3281, grad_fn=<NllLossBackward>)
# tensor([[ 0.0075,  0.0175,  0.0955,  0.0244,  0.0085,  0.0399, -0.1190,  0.0703,
#          -0.1228,  0.0271]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2394, grad_fn=<NllLossBackward>)
# tensor([[ 0.0027,  0.0011,  0.1006, -0.0060,  0.0218,  0.0304, -0.1076,  0.0730,
#          -0.1577,  0.0032]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2982, grad_fn=<NllLossBackward>)
# tensor([[ 0.0002,  0.0144,  0.1054,  0.0245, -0.0199,  0.0979, -0.1145,  0.0822,
#          -0.1747,  0.0201]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4844, grad_fn=<NllLossBackward>)
# tensor([[-0.0183,  0.0044,  0.1091,  0.0157,  0.0108,  0.0259, -0.1172,  0.0731,
#          -0.1355,  0.0211]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1949, grad_fn=<NllLossBackward>)
# tensor([[-8.3041e-03,  7.2462e-03,  1.1212e-01,  1.3853e-02,  8.0152e-03,
#           3.9535e-02, -9.9272e-02,  9.8276e-02, -1.6474e-01, -1.9384e-05]],
#        grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2080, grad_fn=<NllLossBackward>)
# tensor([[-0.0174,  0.0088,  0.1291,  0.0159,  0.0293,  0.0207, -0.1073,  0.0981,
#          -0.1504,  0.0147]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4171, grad_fn=<NllLossBackward>)
# tensor([[-0.0098,  0.0033,  0.1211, -0.0174, -0.0129,  0.0444, -0.1262,  0.0767,
#          -0.1496,  0.0616]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2433, grad_fn=<NllLossBackward>)
# tensor([[-9.3603e-03,  9.0306e-04,  1.2151e-01,  3.4309e-05,  9.8571e-03,
#           1.8317e-02, -1.1499e-01,  8.1694e-02, -1.5428e-01,  3.3191e-02]],
#        grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2944, grad_fn=<NllLossBackward>)
# tensor([[ 0.0134,  0.0022,  0.1085, -0.0153,  0.0167,  0.0058, -0.1129,  0.0865,
#          -0.1584,  0.0469]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3201, grad_fn=<NllLossBackward>)
# tensor([[-0.0034,  0.0037,  0.0937, -0.0239,  0.0348,  0.0019, -0.1097,  0.0933,
#          -0.1561,  0.0245]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2768, grad_fn=<NllLossBackward>)
# tensor([[-0.0020, -0.0005,  0.0986, -0.0004,  0.0235,  0.0094, -0.1124,  0.0641,
#          -0.1556,  0.0130]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4113, grad_fn=<NllLossBackward>)
# tensor([[-0.0057,  0.0236,  0.1149,  0.0184,  0.0161,  0.0416, -0.1177,  0.0719,
#          -0.1426,  0.0268]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2940, grad_fn=<NllLossBackward>)
# tensor([[-0.0100,  0.0230,  0.1067,  0.0185,  0.0056,  0.0593, -0.1168,  0.0950,
#          -0.1638, -0.0119]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2114, grad_fn=<NllLossBackward>)
# tensor([[ 0.0011,  0.0141,  0.1059,  0.0054,  0.0350,  0.0189, -0.1171,  0.0847,
#          -0.1432,  0.0129]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4241, grad_fn=<NllLossBackward>)
# tensor([[-0.0071,  0.0070,  0.1209,  0.0071,  0.0165,  0.0068, -0.1302,  0.0932,
#          -0.1358,  0.0326]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2999, grad_fn=<NllLossBackward>)
# tensor([[ 0.0023,  0.0210,  0.1105,  0.0076,  0.0049,  0.0316, -0.1200,  0.1112,
#          -0.1597,  0.0280]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2886, grad_fn=<NllLossBackward>)
# tensor([[-0.0142,  0.0338,  0.1404,  0.0189,  0.0252,  0.0172, -0.1356,  0.0815,
#          -0.1434,  0.0364]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor([[-0.0165,  0.0028,  0.1167,  0.0114,  0.0192,  0.0154, -0.1131,  0.0894,
#          -0.1505,  0.0270]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4562, grad_fn=<NllLossBackward>)
# tensor([[-0.0059,  0.0056,  0.1054, -0.0028,  0.0107,  0.0269, -0.1125,  0.0590,
#          -0.1513,  0.0280]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4527, grad_fn=<NllLossBackward>)
# tensor([[-0.0160,  0.0115,  0.1150,  0.0214,  0.0124,  0.0318, -0.1201,  0.1040,
#          -0.1369,  0.0130]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3251, grad_fn=<NllLossBackward>)
# tensor([[-0.0071, -0.0015,  0.1078, -0.0037,  0.0360, -0.0033, -0.1116,  0.0809,
#          -0.1401,  0.0262]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2675, grad_fn=<NllLossBackward>)
# tensor([[ 0.0249,  0.0055,  0.0755, -0.0081,  0.0136,  0.0178, -0.1225,  0.0805,
#          -0.1536,  0.0206]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.2757, grad_fn=<NllLossBackward>)
# tensor([[-0.0007,  0.0276,  0.0947,  0.0201,  0.0274,  0.0720, -0.1200,  0.0930,
#          -0.1624,  0.0016]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2391, grad_fn=<NllLossBackward>)
# tensor([[-0.0189,  0.0205,  0.1180,  0.0236,  0.0295,  0.0378, -0.1164,  0.0946,
#          -0.1607,  0.0170]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2725, grad_fn=<NllLossBackward>)
# tensor([[-0.0125, -0.0111,  0.1367, -0.0133,  0.0088,  0.0191, -0.1179,  0.0826,
#          -0.1420,  0.0575]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3177, grad_fn=<NllLossBackward>)
# tensor([[ 0.0021,  0.0154,  0.1028, -0.0122,  0.0201,  0.0166, -0.1151,  0.0723,
#          -0.1449,  0.0282]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2882, grad_fn=<NllLossBackward>)
# tensor([[-0.0056, -0.0074,  0.0972,  0.0050,  0.0285,  0.0107, -0.1019,  0.0823,
#          -0.1517,  0.0139]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4539, grad_fn=<NllLossBackward>)
# tensor([[-0.0032,  0.0154,  0.1080, -0.0004,  0.0108,  0.0199, -0.1168,  0.0713,
#          -0.1421,  0.0308]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2737, grad_fn=<NllLossBackward>)
# tensor([[-0.0103, -0.0021,  0.0957, -0.0009,  0.0178,  0.0114, -0.1063,  0.0909,
#          -0.1595,  0.0141]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3106, grad_fn=<NllLossBackward>)
# tensor([[-0.0204,  0.0041,  0.1433,  0.0134, -0.0030,  0.0255, -0.1091,  0.1081,
#          -0.1329,  0.0429]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2996, grad_fn=<NllLossBackward>)
# tensor([[-0.0030,  0.0156,  0.1031,  0.0083,  0.0216,  0.0234, -0.1247,  0.0909,
#          -0.1421,  0.0160]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2907, grad_fn=<NllLossBackward>)
# tensor([[ 0.0090,  0.0061,  0.0976, -0.0044,  0.0126,  0.0347, -0.1158,  0.0729,
#          -0.1508,  0.0326]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2720, grad_fn=<NllLossBackward>)
# tensor([[ 0.0037,  0.0009,  0.1286,  0.0185, -0.0004,  0.0341, -0.1142,  0.0810,
#          -0.1506,  0.0277]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1799, grad_fn=<NllLossBackward>)
# ...
#          -0.1510,  0.0282]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2010, grad_fn=<NllLossBackward>)
# tensor([[ 0.0055,  0.0145,  0.0836,  0.0206,  0.0143,  0.0497, -0.1284,  0.0977,
#          -0.1619, -0.0168]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2891, grad_fn=<NllLossBackward>)
# tensor([[-0.0105,  0.0047,  0.0972, -0.0063,  0.0104,  0.0169, -0.1138,  0.0778,
#          -0.1554,  0.0248]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2026, grad_fn=<NllLossBackward>)
# tensor([[-0.0046, -0.0131,  0.0964, -0.0124,  0.0421, -0.0073, -0.0964,  0.0817,
#          -0.1488,  0.0215]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.3082, grad_fn=<NllLossBackward>)
# tensor([[ 0.0048,  0.0003,  0.1005,  0.0078,  0.0257,  0.0151, -0.1106,  0.0779,
#          -0.1442,  0.0217]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2793, grad_fn=<NllLossBackward>)
# tensor([[ 0.0013,  0.0082,  0.1191, -0.0008,  0.0224,  0.0122, -0.1171,  0.0842,
#          -0.1444,  0.0369]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4247, grad_fn=<NllLossBackward>)
# tensor([[-0.0126,  0.0266,  0.0949,  0.0317, -0.0125,  0.1040, -0.1240,  0.0888,
#          -0.1775,  0.0129]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3221, grad_fn=<NllLossBackward>)
# tensor([[ 0.0110, -0.0092,  0.0861, -0.0141,  0.0169,  0.0100, -0.1043,  0.0992,
#          -0.1609,  0.0337]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2922, grad_fn=<NllLossBackward>)
# tensor([[-0.0232,  0.0097,  0.1099, -0.0128,  0.0138,  0.0267, -0.1210,  0.0826,
#          -0.1655,  0.0229]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2174, grad_fn=<NllLossBackward>)
# tensor([[-0.0062,  0.0029,  0.1085,  0.0090, -0.0070,  0.0498, -0.1178,  0.0642,
#          -0.1469,  0.0319]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3112, grad_fn=<NllLossBackward>)
# tensor([[ 0.0047,  0.0026,  0.0992,  0.0085,  0.0145,  0.0355, -0.1121,  0.0775,
#          -0.1514,  0.0255]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2911, grad_fn=<NllLossBackward>)
# tensor([[-0.0054,  0.0029,  0.1176,  0.0055,  0.0273,  0.0120, -0.1169,  0.0791,
#          -0.1434,  0.0260]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3003, grad_fn=<NllLossBackward>)
# tensor([[ 0.0021, -0.0005,  0.1135,  0.0012, -0.0046,  0.0553, -0.1067,  0.0723,
#          -0.1567,  0.0143]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2901, grad_fn=<NllLossBackward>)
# tensor([[-0.0031,  0.0004,  0.1170,  0.0054, -0.0104,  0.0459, -0.1131,  0.0801,
#          -0.1583,  0.0439]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2605, grad_fn=<NllLossBackward>)
# tensor([[ 0.0098,  0.0076,  0.1084,  0.0135,  0.0111,  0.0304, -0.1156,  0.0774,
#          -0.1434,  0.0223]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4507, grad_fn=<NllLossBackward>)
# tensor([[-0.0144,  0.0017,  0.1237,  0.0028,  0.0161,  0.0021, -0.1168,  0.0750,
#          -0.1348,  0.0369]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4393, grad_fn=<NllLossBackward>)
# tensor([[-0.0070,  0.0099,  0.1138,  0.0013,  0.0073,  0.0366, -0.1178,  0.0710,
#          -0.1502,  0.0267]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3115, grad_fn=<NllLossBackward>)
# tensor([[ 0.0047,  0.0150,  0.0971,  0.0131,  0.0093,  0.0543, -0.1160,  0.0736,
#          -0.1516,  0.0195]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4588, grad_fn=<NllLossBackward>)
# tensor([[-0.0296,  0.0147,  0.1088,  0.0178,  0.0177,  0.0481, -0.1097,  0.0964,
#          -0.1687, -0.0022]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2087, grad_fn=<NllLossBackward>)
# tensor([[-0.0114,  0.0024,  0.1326,  0.0017,  0.0145,  0.0313, -0.1228,  0.0833,
#          -0.1395,  0.0443]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor([[-0.0029,  0.0207,  0.1177,  0.0117,  0.0342,  0.0182, -0.1155,  0.0978,
#          -0.1494,  0.0347]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.2917, grad_fn=<NllLossBackward>)
# tensor([[-0.0115,  0.0200,  0.1354, -0.0101,  0.0030,  0.0194, -0.1150,  0.0980,
#          -0.1581,  0.0490]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4671, grad_fn=<NllLossBackward>)
# tensor([[ 0.0080,  0.0135,  0.1066,  0.0047,  0.0043,  0.0336, -0.1167,  0.1038,
#          -0.1612,  0.0098]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3020, grad_fn=<NllLossBackward>)
# tensor([[-0.0018, -0.0032,  0.0943, -0.0155,  0.0043,  0.0153, -0.1111,  0.0785,
#          -0.1683,  0.0243]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2727, grad_fn=<NllLossBackward>)
# tensor([[-0.0010,  0.0141,  0.1316,  0.0104, -0.0043,  0.0304, -0.1281,  0.0852,
#          -0.1417,  0.0315]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2781, grad_fn=<NllLossBackward>)
# tensor([[-0.0067,  0.0179,  0.1634,  0.0253, -0.0094,  0.0422, -0.1198,  0.0856,
#          -0.1372,  0.0331]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.3249, grad_fn=<NllLossBackward>)
# tensor([[-0.0125, -0.0178,  0.1197, -0.0154,  0.0043,  0.0084, -0.1158,  0.0797,
#          -0.1424,  0.0648]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3206, grad_fn=<NllLossBackward>)
# tensor([[-0.0070,  0.0119,  0.1041,  0.0070,  0.0159,  0.0157, -0.1133,  0.0752,
#          -0.1533, -0.0022]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2254, grad_fn=<NllLossBackward>)
# tensor([[-0.0033, -0.0017,  0.1363,  0.0052, -0.0226,  0.0276, -0.1135,  0.0624,
#          -0.1284,  0.0430]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2434, grad_fn=<NllLossBackward>)
# tensor([[-0.0158,  0.0142,  0.1229,  0.0129,  0.0030,  0.0418, -0.1081,  0.0798,
#          -0.1488,  0.0302]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2288, grad_fn=<NllLossBackward>)
# tensor([[-0.0111,  0.0118,  0.1254,  0.0269, -0.0004,  0.0449, -0.1111,  0.0981,
#          -0.1445,  0.0043]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2119, grad_fn=<NllLossBackward>)
# tensor([[-0.0105, -0.0065,  0.1163,  0.0125,  0.0058,  0.0362, -0.1158,  0.0854,
#          -0.1417,  0.0190]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3159, grad_fn=<NllLossBackward>)
# tensor([[-0.0123,  0.0009,  0.1148,  0.0097,  0.0151,  0.0330, -0.1108,  0.0803,
#          -0.1548,  0.0242]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2958, grad_fn=<NllLossBackward>)
# tensor([[ 0.0045,  0.0003,  0.1143,  0.0101,  0.0123,  0.0261, -0.1153,  0.0745,
#          -0.1455,  0.0028]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4492, grad_fn=<NllLossBackward>)
# tensor([[-0.0132,  0.0005,  0.1281,  0.0159,  0.0263,  0.0022, -0.1092,  0.0776,
#          -0.1329, -0.0012]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2887, grad_fn=<NllLossBackward>)
# tensor([[ 0.0148,  0.0170,  0.1016,  0.0090,  0.0308,  0.0316, -0.1165,  0.1061,
#          -0.1555,  0.0126]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3017, grad_fn=<NllLossBackward>)
# tensor([[-0.0566,  0.0164,  0.1408,  0.0219, -0.0239,  0.0974, -0.1095,  0.1048,
#          -0.1935,  0.0368]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3673, grad_fn=<NllLossBackward>)
# tensor([[ 0.0107,  0.0084,  0.1201,  0.0075,  0.0057,  0.0379, -0.1185,  0.0928,
#          -0.1502,  0.0215]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2713, grad_fn=<NllLossBackward>)
# tensor([[-0.0007,  0.0069,  0.1172,  0.0051,  0.0134,  0.0202, -0.1135,  0.0733,
#          -0.1421,  0.0165]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2316, grad_fn=<NllLossBackward>)
# tensor([[-0.0183,  0.0052,  0.1285,  0.0112, -0.0021,  0.0307, -0.1215,  0.0939,
#          -0.1407,  0.0206]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3247, grad_fn=<NllLossBackward>)
# tensor([[ 0.0140,  0.0005,  0.1007, -0.0017,  0.0052,  0.0323, -0.1218,  0.0727,
#          -0.1512,  0.0262]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4541, grad_fn=<NllLossBackward>)
# tensor([[-0.0058,  0.0087,  0.1166,  0.0079,  0.0004,  0.0415, -0.1193,  0.0799,
#          -0.1618,  0.0357]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3119, grad_fn=<NllLossBackward>)
# tensor([[-0.0083,  0.0082,  0.1269,  0.0132,  0.0102,  0.0380, -0.1172,  0.0879,
#          -0.1471,  0.0267]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3178, grad_fn=<NllLossBackward>)
# tensor([[ 0.0009,  0.0251,  0.1168,  0.0047,  0.0090,  0.0195, -0.1125,  0.0792,
#          -0.1464,  0.0285]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2793, grad_fn=<NllLossBackward>)
# tensor([[-0.0059,  0.0208,  0.1151,  0.0281,  0.0453,  0.0265, -0.1137,  0.1027,
#          -0.1536,  0.0009]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1972, grad_fn=<NllLossBackward>)
# tensor([[-0.0006,  0.0242,  0.1000,  0.0226,  0.0129,  0.0501, -0.1191,  0.1122,
#          -0.1568, -0.0087]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2095, grad_fn=<NllLossBackward>)
# tensor([[ 0.0005,  0.0131,  0.1094,  0.0059,  0.0016,  0.0392, -0.1269,  0.0938,
#          -0.1473,  0.0188]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3005, grad_fn=<NllLossBackward>)
# tensor([[-0.0099,  0.0062,  0.1317,  0.0006,  0.0219,  0.0221, -0.1125,  0.0811,
#          -0.1597,  0.0337]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2853, grad_fn=<NllLossBackward>)
# tensor([[-0.0100, -0.0008,  0.1075,  0.0059,  0.0005,  0.0287, -0.1174,  0.0738,
#          -0.1413,  0.0265]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4438, grad_fn=<NllLossBackward>)
# tensor([[ 0.0037,  0.0040,  0.1073,  0.0171, -0.0017,  0.0625, -0.1134,  0.0775,
#          -0.1553,  0.0124]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1995, grad_fn=<NllLossBackward>)
# tensor([[-0.0074,  0.0157,  0.0982, -0.0119,  0.0309,  0.0177, -0.1091,  0.0988,
#          -0.1687,  0.0329]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.2071, grad_fn=<NllLossBackward>)
# tensor([[-0.0067,  0.0105,  0.1372,  0.0080,  0.0030,  0.0348, -0.1181,  0.0809,
#          -0.1428,  0.0458]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4290, grad_fn=<NllLossBackward>)
# tensor([[-0.0144,  0.0286,  0.1377,  0.0168,  0.0035,  0.0557, -0.1251,  0.0869,
#          -0.1540,  0.0441]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2973, grad_fn=<NllLossBackward>)
# tensor([[-0.0195,  0.0110,  0.1363,  0.0165,  0.0027,  0.0327, -0.1209,  0.0813,
#          -0.1499,  0.0135]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2896, grad_fn=<NllLossBackward>)
# tensor([[-0.0049,  0.0146,  0.0968,  0.0060,  0.0295,  0.0096, -0.1172,  0.0699,
#          -0.1356,  0.0172]], grad_fn=<AddmmBackward>)
# tensor([6])
# tensor(2.4207, grad_fn=<NllLossBackward>)
# tensor([[-0.0074,  0.0147,  0.1099,  0.0211,  0.0309,  0.0248, -0.1187,  0.0870,
#          -0.1407,  0.0073]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1983, grad_fn=<NllLossBackward>)
# tensor([[ 0.0103, -0.0019,  0.1042, -0.0133,  0.0164,  0.0155, -0.1002,  0.0715,
#          -0.1667,  0.0096]], grad_fn=<AddmmBackward>)
# tensor([9])
# tensor(2.2902, grad_fn=<NllLossBackward>)
# tensor([[ 0.0125, -0.0027,  0.0906, -0.0108,  0.0275,  0.0129, -0.1207,  0.0783,
#          -0.1523,  0.0222]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2735, grad_fn=<NllLossBackward>)
# tensor([[-0.0122, -0.0054,  0.1025, -0.0006,  0.0036,  0.0350, -0.0963,  0.0810,
#          -0.1684,  0.0149]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3129, grad_fn=<NllLossBackward>)
# tensor([[-0.0174,  0.0090,  0.1446,  0.0029,  0.0207,  0.0285, -0.1064,  0.0854,
#          -0.1538,  0.0261]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3008, grad_fn=<NllLossBackward>)
# tensor([[ 0.0106,  0.0090,  0.1025,  0.0191,  0.0008,  0.0419, -0.1211,  0.0914,
#          -0.1523, -0.0110]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2132, grad_fn=<NllLossBackward>)
# tensor([[ 0.0051,  0.0086,  0.1266,  0.0254,  0.0031,  0.0579, -0.1213,  0.0929,
#          -0.1445,  0.0212]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2554, grad_fn=<NllLossBackward>)
# tensor([[-0.0262,  0.0122,  0.1502,  0.0012, -0.0135,  0.0323, -0.1041,  0.0962,
#          -0.1492,  0.0651]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2802, grad_fn=<NllLossBackward>)
# tensor([[-0.0166, -0.0008,  0.1266,  0.0081,  0.0304,  0.0109, -0.1070,  0.0920,
#          -0.1391,  0.0169]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2155, grad_fn=<NllLossBackward>)
# tensor([[-0.0147,  0.0078,  0.1053,  0.0036,  0.0228,  0.0258, -0.1118,  0.0773,
#          -0.1554,  0.0238]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3002, grad_fn=<NllLossBackward>)
# tensor([[ 0.0057,  0.0260,  0.0834,  0.0336,  0.0286,  0.0349, -0.1292,  0.0923,
#          -0.1460, -0.0142]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3012, grad_fn=<NllLossBackward>)
# tensor([[ 0.0009,  0.0150,  0.1114,  0.0153,  0.0219,  0.0233, -0.1144,  0.0875,
#          -0.1416,  0.0315]], grad_fn=<AddmmBackward>)
# tensor([4])
# tensor(2.2885, grad_fn=<NllLossBackward>)
# tensor([[-0.0225,  0.0074,  0.1309,  0.0160,  0.0097,  0.0375, -0.1237,  0.0855,
#          -0.1338,  0.0292]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1783, grad_fn=<NllLossBackward>)
# tensor([[-0.0029,  0.0032,  0.1045,  0.0060,  0.0223,  0.0201, -0.1185,  0.0867,
#          -0.1328,  0.0171]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3086, grad_fn=<NllLossBackward>)
# tensor([[-0.0080,  0.0104,  0.1121,  0.0163,  0.0281,  0.0316, -0.1172,  0.0970,
#          -0.1445,  0.0306]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2142, grad_fn=<NllLossBackward>)
# tensor([[-0.0092,  0.0285,  0.1194, -0.0027,  0.0174,  0.0106, -0.1189,  0.0973,
#          -0.1633,  0.0358]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2968, grad_fn=<NllLossBackward>)
# tensor([[-0.0036,  0.0138,  0.1154,  0.0244,  0.0065,  0.0676, -0.1167,  0.0862,
#          -0.1468,  0.0146]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4585, grad_fn=<NllLossBackward>)
# tensor([[-0.0062,  0.0054,  0.1207,  0.0009, -0.0064,  0.0280, -0.1149,  0.0754,
#          -0.1577,  0.0367]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.3100, grad_fn=<NllLossBackward>)
# tensor([[ 0.0119,  0.0110,  0.1147,  0.0045,  0.0028,  0.0429, -0.1276,  0.0854,
#          -0.1481,  0.0174]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4552, grad_fn=<NllLossBackward>)
# tensor([[-0.0085,  0.0156,  0.1144,  0.0116,  0.0142,  0.0446, -0.1148,  0.0882,
#          -0.1540,  0.0362]], grad_fn=<AddmmBackward>)
# tensor([2])
# tensor(2.1960, grad_fn=<NllLossBackward>)
# tensor([[-0.0277,  0.0162,  0.1426,  0.0243, -0.0068,  0.0316, -0.1171,  0.1061,
#          -0.1516, -0.0072]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2010, grad_fn=<NllLossBackward>)
# tensor([[ 0.0150,  0.0050,  0.1055,  0.0020,  0.0002,  0.0309, -0.1182,  0.0819,
#          -0.1400,  0.0303]], grad_fn=<AddmmBackward>)
# tensor([0])
# tensor(2.2915, grad_fn=<NllLossBackward>)
# tensor([[-0.0060,  0.0295,  0.1287,  0.0114,  0.0107,  0.0402, -0.1096,  0.0977,
#          -0.1663,  0.0193]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3001, grad_fn=<NllLossBackward>)
# tensor([[-0.0069,  0.0069,  0.1177,  0.0049, -0.0033,  0.0362, -0.1321,  0.0967,
#          -0.1481,  0.0302]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.2698, grad_fn=<NllLossBackward>)
# tensor([[-0.0035,  0.0045,  0.1192,  0.0089,  0.0169,  0.0317, -0.1232,  0.0886,
#          -0.1628,  0.0330]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.2983, grad_fn=<NllLossBackward>)
# tensor([[-0.0139,  0.0308,  0.1522,  0.0125, -0.0346,  0.0777, -0.1302,  0.0899,
#          -0.1687,  0.0440]], grad_fn=<AddmmBackward>)
# tensor([8])
# tensor(2.4815, grad_fn=<NllLossBackward>)
# tensor([[-0.0118,  0.0104,  0.1173, -0.0061,  0.0108,  0.0288, -0.1232,  0.0835,
#          -0.1593,  0.0254]], grad_fn=<AddmmBackward>)
# tensor([3])
# tensor(2.3094, grad_fn=<NllLossBackward>)
# tensor([[-0.0089,  0.0041,  0.1442,  0.0065,  0.0178,  0.0054, -0.1197,  0.0757,
#          -0.1332,  0.0219]], grad_fn=<AddmmBackward>)
# tensor([5])
# tensor(2.3015, grad_fn=<NllLossBackward>)
# tensor([[-0.0012,  0.0106,  0.1386,  0.0186, -0.0122,  0.0421, -0.1253,  0.0902,
#          -0.1501,  0.0447]], grad_fn=<AddmmBackward>)
# tensor([1])
# tensor(2.3011, grad_fn=<NllLossBackward>)
# tensor([[-0.0049,  0.0029,  0.1153,  0.0143,  0.0116,  0.0188, -0.1083,  0.0804,
#          -0.1459,  0.0191]], grad_fn=<AddmmBackward>)
# tensor([7])
# tensor(2.2251, grad_fn=<NllLossBackward>)

# %%
# -*- coding: utf-8 -*-
# 优化器

import torch
import torchvision
from torch import nn
from torch.nn import Sequential, Conv2d, MaxPool2d, Flatten, Linear
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader

dataset = torchvision.datasets.CIFAR10("./dataset", train=False, transform=torchvision.transforms.ToTensor(),
                                       download=True)

dataloader = DataLoader(dataset, batch_size=1)

class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.model1 = Sequential(
            Conv2d(3, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024, 64),
            Linear(64, 10)
        )

    def forward(self, x):
        x = self.model1(x)
        return x

print(torch.cuda.is_available())

loss = nn.CrossEntropyLoss()
tudui = Tudui()
# 优化器，随机梯度下降
# 越小越稳定但是越慢
optim = torch.optim.SGD(tudui.parameters(), lr=0.01)
# 共设置20行
for epoch in range(20):
    running_loss = 0.0
    for data in dataloader:
        imgs, targets = data
        outputs = tudui(imgs)
        result_loss = loss(outputs, targets)
        # 梯度置为0
        optim.zero_grad()
        result_loss.backward() # 反向传播
        optim.step()
        running_loss = running_loss + result_loss
    print(running_loss)
# Out:
# Files already downloaded and verified
# True
# tensor(18711.4141, grad_fn=<AddBackward0>)
# tensor(16165.3047, grad_fn=<AddBackward0>)
# tensor(15427.0469, grad_fn=<AddBackward0>)
# tensor(15937.6719, grad_fn=<AddBackward0>)
# tensor(17671.1816, grad_fn=<AddBackward0>)
# tensor(20245.6582, grad_fn=<AddBackward0>)
# tensor(22509.2695, grad_fn=<AddBackward0>)
# tensor(23339.5762, grad_fn=<AddBackward0>)
# tensor(24309.5078, grad_fn=<AddBackward0>)
# tensor(25269.2285, grad_fn=<AddBackward0>)
# tensor(25497.5527, grad_fn=<AddBackward0>)
# tensor(26182.8047, grad_fn=<AddBackward0>)
# tensor(26371.4180, grad_fn=<AddBackward0>)
# tensor(27834.2754, grad_fn=<AddBackward0>)
# tensor(29662.1348, grad_fn=<AddBackward0>)
# tensor(32659.7441, grad_fn=<AddBackward0>)
# tensor(nan, grad_fn=<AddBackward0>)
# tensor(nan, grad_fn=<AddBackward0>)
# tensor(nan, grad_fn=<AddBackward0>)
# tensor(nan, grad_fn=<AddBackward0>)

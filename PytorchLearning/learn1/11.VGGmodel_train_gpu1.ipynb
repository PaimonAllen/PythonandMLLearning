# %%
# -*- coding: utf-8 -*-
# VGG模型，GPU模式

import torch
import torchvision
from torch.utils.tensorboard import SummaryWriter

# from model import *
# 准备数据集
from torch import nn
from torch.utils.data import DataLoader

train_data = torchvision.datasets.CIFAR10(root="./dataset", train=True, transform=torchvision.transforms.ToTensor(),
                                          download=True)
test_data = torchvision.datasets.CIFAR10(root="./dataset", train=False, transform=torchvision.transforms.ToTensor(),
                                         download=True)

# length 长度
train_data_size = len(train_data)
test_data_size = len(test_data)
# 如果train_data_size=10, 训练数据集的长度为：10
print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))


# 利用 DataLoader 来加载数据集
train_dataloader = DataLoader(train_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# 创建网络模型


class VGG(nn.Module):
    def __init__(self):
        super(VGG, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64*4*4, 64),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        x = self.model(x)
        return x


vgg = VGG()
if torch.cuda.is_available():
    vgg = vgg.cuda(1)
    # vgg=vgg.cuda()

# 损失函数
loss_fn = nn.CrossEntropyLoss()
if torch.cuda.is_available():
    loss_fn = loss_fn.cuda(1)
# 优化器
# learning_rate = 0.01
# 1e-2=1 x (10)^(-2) = 1 /100 = 0.01
learning_rate = 1e-3
optimizer = torch.optim.SGD(vgg.parameters(), lr=learning_rate)

# 设置训练网络的一些参数
# 记录训练的次数
total_train_step = 0
# 记录测试的次数
total_test_step = 0
# 训练的轮数
epoch = 20

# 添加tensorboard
writer = SummaryWriter("./logs_train")

for i in range(epoch):
    print("-------第 {} 轮训练开始-------".format(i+1))

    # 训练步骤开始
    vgg.train()
    for data in train_dataloader:
        imgs, targets = data
        if torch.cuda.is_available():
            imgs = imgs.cuda(1)
            targets = targets.cuda(1)
        outputs = vgg(imgs)
        loss = loss_fn(outputs, targets)

        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step = total_train_step + 1
        if total_train_step % 100 == 0:
            print("训练次数：{}, Loss: {}".format(total_train_step, loss.item()))
            writer.add_scalar("train_loss", loss.item(), total_train_step)

    # 测试步骤开始
    vgg.eval()
    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in test_dataloader:
            imgs, targets = data
            if torch.cuda.is_available():
                imgs = imgs.cuda(1)
                targets = targets.cuda(1)
            outputs = vgg(imgs)
            loss = loss_fn(outputs, targets)
            total_test_loss = total_test_loss + loss.item()
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy = total_accuracy + accuracy

    print("整体测试集上的Loss: {}".format(total_test_loss))
    print("整体测试集上的正确率: {}".format(total_accuracy/test_data_size))
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    writer.add_scalar("test_accuracy", total_accuracy /
                      test_data_size, total_test_step)
    total_test_step = total_test_step + 1

    # torch.save(
    #     vgg, "/home/tzr/Documents/GitHubSYNC/PythonandMLLearning/PytorchLearning/demo1/vggmodel/vgg_{}.pth".format(i))
    print("模型已保存")

writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练数据集的长度为：50000
# 测试数据集的长度为：10000
# -------第 1 轮训练开始-------
# 训练次数：100, Loss: 2.300337791442871
# 训练次数：200, Loss: 2.3062617778778076
# 训练次数：300, Loss: 2.3001627922058105
# 训练次数：400, Loss: 2.3019425868988037
# 训练次数：500, Loss: 2.3036768436431885
# 训练次数：600, Loss: 2.2977333068847656
# 训练次数：700, Loss: 2.28792667388916
# 整体测试集上的Loss: 361.1705620288849
# 整体测试集上的正确率: 0.1396999955177307
# 模型已保存
# -------第 2 轮训练开始-------
# 训练次数：800, Loss: 2.3000893592834473
# 训练次数：900, Loss: 2.3025388717651367
# 训练次数：1000, Loss: 2.3092219829559326
# 训练次数：1100, Loss: 2.31466007232666
# 训练次数：1200, Loss: 2.3033361434936523
# 训练次数：1300, Loss: 2.290580987930298
# 训练次数：1400, Loss: 2.2993721961975098
# 训练次数：1500, Loss: 2.3054358959198
# 整体测试集上的Loss: 360.28485202789307
# 整体测试集上的正确率: 0.10929999500513077
# 模型已保存
# -------第 3 轮训练开始-------
# 训练次数：1600, Loss: 2.297616481781006
# 训练次数：1700, Loss: 2.286269187927246
# 训练次数：1800, Loss: 2.2976343631744385
# 训练次数：1900, Loss: 2.2758255004882812
# 训练次数：2000, Loss: 2.270477771759033
# 训练次数：2100, Loss: 2.2862396240234375
# 训练次数：2200, Loss: 2.2769203186035156
# 训练次数：2300, Loss: 2.2805967330932617
# 整体测试集上的Loss: 358.8532691001892
# 整体测试集上的正确率: 0.11249999701976776
# 模型已保存
# -------第 4 轮训练开始-------
# 训练次数：2400, Loss: 2.288161277770996
# 训练次数：2500, Loss: 2.291933298110962
# 训练次数：2600, Loss: 2.2840521335601807
# 训练次数：2700, Loss: 2.2747011184692383
# 训练次数：2800, Loss: 2.2874646186828613
# 训练次数：2900, Loss: 2.2782516479492188
# 训练次数：3000, Loss: 2.272026300430298
# 训练次数：3100, Loss: 2.26954984664917
# 整体测试集上的Loss: 355.92604875564575
# 整体测试集上的正确率: 0.14229999482631683
# 模型已保存
# -------第 5 轮训练开始-------
# 训练次数：3200, Loss: 2.254288673400879
# 训练次数：3300, Loss: 2.2565855979919434
# 训练次数：3400, Loss: 2.2493855953216553
# 训练次数：3500, Loss: 2.2315473556518555
# 训练次数：3600, Loss: 2.255977153778076
# 训练次数：3700, Loss: 2.2325997352600098
# 训练次数：3800, Loss: 2.214583158493042
# 训练次数：3900, Loss: 2.20371150970459
# 整体测试集上的Loss: 348.96821761131287
# 整体测试集上的正确率: 0.18239998817443848
# 模型已保存
# -------第 6 轮训练开始-------
# 训练次数：4000, Loss: 2.243313789367676
# 训练次数：4100, Loss: 2.2016029357910156
# 训练次数：4200, Loss: 2.1913790702819824
# 训练次数：4300, Loss: 2.2190158367156982
# 训练次数：4400, Loss: 2.212404727935791
# 训练次数：4500, Loss: 2.1536357402801514
# 训练次数：4600, Loss: 2.163789987564087
# 整体测试集上的Loss: 336.6390504837036
# 整体测试集上的正确率: 0.21769998967647552
# 模型已保存
# -------第 7 轮训练开始-------
# 训练次数：4700, Loss: 2.1330060958862305
# 训练次数：4800, Loss: 2.2339134216308594
# 训练次数：4900, Loss: 2.0833957195281982
# 训练次数：5000, Loss: 2.0780839920043945
# 训练次数：5100, Loss: 2.030088424682617
# 训练次数：5200, Loss: 2.089590311050415
# 训练次数：5300, Loss: 2.007575511932373
# 训练次数：5400, Loss: 2.057746171951294
# 整体测试集上的Loss: 322.8791664838791
# 整体测试集上的正确率: 0.26899999380111694
# 模型已保存
# -------第 8 轮训练开始-------
# 训练次数：5500, Loss: 2.0258560180664062
# 训练次数：5600, Loss: 1.9302399158477783
# 训练次数：5700, Loss: 2.138784170150757
# 训练次数：5800, Loss: 1.9110379219055176
# 训练次数：5900, Loss: 2.0917346477508545
# 训练次数：6000, Loss: 2.0982470512390137
# 训练次数：6100, Loss: 1.9307576417922974
# 训练次数：6200, Loss: 1.8352081775665283
# 整体测试集上的Loss: 313.66688549518585
# 整体测试集上的正确率: 0.2847000062465668
# 模型已保存
# -------第 9 轮训练开始-------
# 训练次数：6300, Loss: 1.9599312543869019
# 训练次数：6400, Loss: 1.8404253721237183
# 训练次数：6500, Loss: 2.1775901317596436
# 训练次数：6600, Loss: 2.0190329551696777
# 训练次数：6700, Loss: 1.8950763940811157
# 训练次数：6800, Loss: 1.895444631576538
# 训练次数：6900, Loss: 2.037496566772461
# 训练次数：7000, Loss: 1.9261395931243896
# 整体测试集上的Loss: 310.1954149007797
# 整体测试集上的正确率: 0.29420000314712524
# 模型已保存
# -------第 10 轮训练开始-------
# 训练次数：7100, Loss: 2.091010332107544
# 训练次数：7200, Loss: 1.9289991855621338
# 训练次数：7300, Loss: 2.082636833190918
# 训练次数：7400, Loss: 1.7822291851043701
# 训练次数：7500, Loss: 2.0477888584136963
# 训练次数：7600, Loss: 1.9378831386566162
# 训练次数：7700, Loss: 2.0462615489959717
# 训练次数：7800, Loss: 1.9039214849472046
# 整体测试集上的Loss: 307.15136682987213
# 整体测试集上的正确率: 0.3057999908924103
# 模型已保存
# -------第 11 轮训练开始-------
# 训练次数：7900, Loss: 2.096907138824463
# 训练次数：8000, Loss: 1.9799598455429077
# 训练次数：8100, Loss: 1.812831997871399
# 训练次数：8200, Loss: 1.892071008682251
# 训练次数：8300, Loss: 1.9362528324127197
# 训练次数：8400, Loss: 1.9744901657104492
# 训练次数：8500, Loss: 1.9905109405517578
# 训练次数：8600, Loss: 1.8001919984817505
# 整体测试集上的Loss: 303.68359887599945
# 整体测试集上的正确率: 0.320499986410141
# 模型已保存
# -------第 12 轮训练开始-------
# 训练次数：8700, Loss: 1.9201316833496094
# 训练次数：8800, Loss: 1.8402553796768188
# 训练次数：8900, Loss: 1.9353229999542236
# 训练次数：9000, Loss: 1.988742470741272
# 训练次数：9100, Loss: 1.9294772148132324
# 训练次数：9200, Loss: 1.9136905670166016
# 训练次数：9300, Loss: 1.9750512838363647
# 整体测试集上的Loss: 299.57009518146515
# 整体测试集上的正确率: 0.32979997992515564
# 模型已保存
# -------第 13 轮训练开始-------
# 训练次数：9400, Loss: 1.7597159147262573
# 训练次数：9500, Loss: 2.0075886249542236
# 训练次数：9600, Loss: 1.9699496030807495
# 训练次数：9700, Loss: 1.988394856452942
# 训练次数：9800, Loss: 1.8157048225402832
# 训练次数：9900, Loss: 1.8211395740509033
# 训练次数：10000, Loss: 1.8585350513458252
# 训练次数：10100, Loss: 1.998458981513977
# 整体测试集上的Loss: 294.77657556533813
# 整体测试集上的正确率: 0.3446999788284302
# 模型已保存
# -------第 14 轮训练开始-------
# 训练次数：10200, Loss: 1.7324992418289185
# 训练次数：10300, Loss: 1.739078164100647
# 训练次数：10400, Loss: 1.9612882137298584
# 训练次数：10500, Loss: 1.8973618745803833
# 训练次数：10600, Loss: 1.8848381042480469
# 训练次数：10700, Loss: 1.5827758312225342
# 训练次数：10800, Loss: 1.7126059532165527
# 训练次数：10900, Loss: 1.8249101638793945
# 整体测试集上的Loss: 289.830282330513
# 整体测试集上的正确率: 0.35519999265670776
# 模型已保存
# -------第 15 轮训练开始-------
# 训练次数：11000, Loss: 1.8309803009033203
# 训练次数：11100, Loss: 1.8450751304626465
# 训练次数：11200, Loss: 1.7712969779968262
# 训练次数：11300, Loss: 1.7725677490234375
# 训练次数：11400, Loss: 1.575453281402588
# 训练次数：11500, Loss: 2.0529003143310547
# 训练次数：11600, Loss: 1.911771297454834
# 训练次数：11700, Loss: 1.9879544973373413
# 整体测试集上的Loss: 285.0552487373352
# 整体测试集上的正确率: 0.36419999599456787
# 模型已保存
# -------第 16 轮训练开始-------
# 训练次数：11800, Loss: 1.7923791408538818
# 训练次数：11900, Loss: 1.7368122339248657
# 训练次数：12000, Loss: 1.745656967163086
# 训练次数：12100, Loss: 1.6443915367126465
# 训练次数：12200, Loss: 1.88520348072052
# 训练次数：12300, Loss: 1.622194528579712
# 训练次数：12400, Loss: 1.7798583507537842
# 训练次数：12500, Loss: 1.5602751970291138
# 整体测试集上的Loss: 280.39466738700867
# 整体测试集上的正确率: 0.3725000023841858
# 模型已保存
# -------第 17 轮训练开始-------
# 训练次数：12600, Loss: 1.5437231063842773
# 训练次数：12700, Loss: 1.7528232336044312
# 训练次数：12800, Loss: 1.709983229637146
# 训练次数：12900, Loss: 1.9247145652770996
# 训练次数：13000, Loss: 1.904939889907837
# 训练次数：13100, Loss: 1.7689414024353027
# 训练次数：13200, Loss: 1.6081862449645996
# 整体测试集上的Loss: 276.1402145624161
# 整体测试集上的正确率: 0.37869998812675476
# 模型已保存
# -------第 18 轮训练开始-------
# 训练次数：13300, Loss: 1.6330933570861816
# 训练次数：13400, Loss: 1.6466002464294434
# 训练次数：13500, Loss: 1.8168389797210693
# 训练次数：13600, Loss: 1.8308894634246826
# 训练次数：13700, Loss: 1.5454187393188477
# 训练次数：13800, Loss: 1.7167972326278687
# 训练次数：13900, Loss: 1.6378378868103027
# 训练次数：14000, Loss: 1.7492808103561401
# 整体测试集上的Loss: 272.67319881916046
# 整体测试集上的正确率: 0.38609999418258667
# 模型已保存
# -------第 19 轮训练开始-------
# 训练次数：14100, Loss: 1.728255271911621
# 训练次数：14200, Loss: 1.7160900831222534
# 训练次数：14300, Loss: 1.8542346954345703
# 训练次数：14400, Loss: 1.7957217693328857
# 训练次数：14500, Loss: 1.629043459892273
# 训练次数：14600, Loss: 1.808527946472168
# 训练次数：14700, Loss: 1.7250339984893799
# 训练次数：14800, Loss: 1.8577747344970703
# 整体测试集上的Loss: 270.0603930950165
# 整体测试集上的正确率: 0.38670000433921814
# 模型已保存
# -------第 20 轮训练开始-------
# 训练次数：14900, Loss: 1.6601412296295166
# 训练次数：15000, Loss: 1.7434606552124023
# 训练次数：15100, Loss: 1.5947891473770142
# 训练次数：15200, Loss: 1.7069638967514038
# 训练次数：15300, Loss: 1.6639264822006226
# 训练次数：15400, Loss: 1.7322691679000854
# 训练次数：15500, Loss: 1.8141701221466064
# 训练次数：15600, Loss: 1.598050832748413
# 整体测试集上的Loss: 268.0449254512787
# 整体测试集上的正确率: 0.39089998602867126
# 模型已保存

# %%
# -*- coding: utf-8 -*-
import torch
from torch.nn import L1Loss
from torch import nn

inputs = torch.tensor([1, 2, 3], dtype=torch.float32)
targets = torch.tensor([1, 2, 5], dtype=torch.float32)

inputs = torch.reshape(inputs, (1, 1, 1, 3))
targets = torch.reshape(targets, (1, 1, 1, 3))

loss = L1Loss(reduction='sum')
result = loss(inputs, targets)

loss_mse = nn.MSELoss()
result_mse = loss_mse(inputs, targets)

print(result)
print(result_mse)
#
#
# 测试CrossEntropyLoss
x = torch.tensor([0.1, 0.2, 0.3])
y = torch.tensor([1])
x = torch.reshape(x, (1, 3))
loss_cross = nn.CrossEntropyLoss()
result_cross = loss_cross(x, y)
print(result_cross)
# Out:
# tensor(2.)
# tensor(1.3333)
# tensor(1.1019)

# %%
# -*- coding: utf-8 -*-

import torchvision
from torch import nn
from torch.nn import Sequential, Conv2d, MaxPool2d, Flatten, Linear
from torch.utils.data import DataLoader

dataset = torchvision.datasets.CIFAR10("dataset/", train=False, transform=torchvision.transforms.ToTensor(),
                                       download=True)

dataloader = DataLoader(dataset, batch_size=1)

class MyNN(nn.Module):
    def __init__(self):
        super(MyNN, self).__init__()
        self.model1 = Sequential(
            Conv2d(3, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024, 64),
            Linear(64, 10)
        )

    def forward(self, x):
        x = self.model1(x)
        return x

# 交叉熵
loss = nn.CrossEntropyLoss()

myNN = MyNN()
for data in dataloader:
    imgs, targets = data
    outputs = myNN(imgs)
    result_loss = loss(outputs, targets)
    print(result_loss)
    print("ok")
# Out:
# Files already downloaded and verified
# tensor(2.3681, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3031, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3038, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3803, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3905, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1730, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3815, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3731, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1688, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2545, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2451, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2646, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3024, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2381, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3080, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2769, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2922, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3079, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3810, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2866, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2624, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4183, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2382, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2650, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4093, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4008, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2469, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2395, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3875, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3841, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2646, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4106, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2490, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2514, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4123, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3982, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1242, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2399, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2749, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3972, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3889, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2566, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3768, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2443, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2299, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3763, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2415, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2871, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3781, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2610, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2960, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2430, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3648, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2948, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3051, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2912, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2921, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3989, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3852, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2900, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3694, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3881, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3693, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3866, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4110, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1576, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4054, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3644, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2824, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3953, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3803, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3056, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3054, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2308, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3988, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2388, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3524, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3587, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3135, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3131, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1762, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1634, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2928, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3872, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2539, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4000, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2859, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3139, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2524, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2431, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3686, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3064, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3838, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4161, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3826, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3869, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2548, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2559, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2940, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4070, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2588, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3903, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3732, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1545, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1795, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3752, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3907, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3213, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2727, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4014, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2547, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3893, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3976, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1713, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3542, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2436, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3959, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2876, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3141, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3685, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1534, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3985, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3179, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2577, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2971, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3682, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2414, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4036, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3993, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1483, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3006, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2268, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1614, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4120, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2429, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2890, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4051, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2308, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3825, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2837, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3740, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3566, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2894, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2835, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3866, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3881, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4033, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2928, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2521, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3844, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2530, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2584, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2587, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4107, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2472, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2475, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4014, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3924, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1651, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3927, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3826, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2968, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4189, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4189, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2608, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2316, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2400, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2287, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2317, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2905, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2463, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2467, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3894, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2888, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2559, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2361, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2490, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2811, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3977, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4065, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3768, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3108, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3885, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3683, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3726, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2638, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2867, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2994, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2482, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1617, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2882, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4120, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3075, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3160, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2882, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3130, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2568, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1553, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3089, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2961, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1602, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3620, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2750, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2854, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2348, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2887, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4090, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2817, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2394, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3032, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2583, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2323, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3244, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4011, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3857, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2329, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4147, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3599, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2488, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3830, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3900, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3756, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2562, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1834, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2576, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3107, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3088, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2410, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4170, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2351, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2776, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2716, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1354, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1416, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3063, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2397, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2516, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3586, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1686, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2321, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4022, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4177, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2537, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3573, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2243, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2425, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3976, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2498, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3543, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2377, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2209, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3122, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1605, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2377, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2913, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2398, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3099, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4049, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4231, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2980, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2684, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4100, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3724, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3870, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3502, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3108, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2491, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2369, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3691, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3933, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3727, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2439, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2411, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3743, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1813, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2489, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2418, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1346, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2457, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2888, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2349, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1510, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4105, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3888, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2451, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3715, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4006, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3877, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2444, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3815, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3872, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3753, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3696, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4089, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3844, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1581, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3056, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3935, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1500, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3848, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3046, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3887, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3150, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2692, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3920, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2482, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2808, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2904, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2585, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2645, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3715, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2725, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3973, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3542, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4253, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1565, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2913, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2629, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4004, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3795, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1508, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2447, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3655, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3865, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3805, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2477, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3555, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2993, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2511, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3027, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4079, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3833, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4035, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2763, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2990, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2499, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3848, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3873, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3139, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2338, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2332, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1760, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2429, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3816, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3975, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2811, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3691, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4053, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2976, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2378, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2724, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3042, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1583, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2327, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3910, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1787, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3593, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3173, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1516, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3984, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2925, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2457, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4011, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4229, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2934, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2535, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2855, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2525, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3842, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3855, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2414, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2575, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2264, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4071, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3161, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2835, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4112, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4059, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2643, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1638, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4096, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3739, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4047, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2464, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3771, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4178, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3654, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2341, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3667, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2453, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3153, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2987, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3095, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3038, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4250, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2579, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1665, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3106, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3905, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2994, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2272, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3631, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3899, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1736, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2365, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2550, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2743, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3738, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2909, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4356, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2693, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2373, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2443, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4071, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2313, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3636, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2407, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3756, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3943, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2893, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3607, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3018, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3561, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2844, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3993, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2497, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3553, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1654, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1530, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4155, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2304, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2371, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2800, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2874, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2692, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2579, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4024, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4034, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3818, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2535, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2844, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3713, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2392, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3777, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3653, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2654, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3983, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3819, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2517, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3851, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1732, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4075, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3743, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3794, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3963, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3721, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3002, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3133, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3577, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2893, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3126, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2554, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2450, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2895, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3815, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2355, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2590, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4102, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3042, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3838, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3086, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2708, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2652, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2406, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2387, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2361, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2761, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2604, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1610, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2231, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3090, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1371, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1496, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3212, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2230, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4022, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4082, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2563, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4002, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3845, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2632, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4151, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2465, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3742, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2943, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2431, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2307, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4144, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2875, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3855, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3844, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1670, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2670, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3658, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2990, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2321, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2574, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3078, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2851, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2904, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2591, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2885, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2562, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2720, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2534, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2494, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4077, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3914, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2480, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2529, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2391, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2797, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3857, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3839, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3837, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4058, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2485, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2393, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1664, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2930, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3752, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2896, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2790, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2485, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1461, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3818, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4055, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2800, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2486, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2574, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3129, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2588, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2358, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4033, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3838, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4243, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3798, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4017, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2575, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2875, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3786, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3985, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4208, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3602, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2363, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2894, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2401, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3968, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3794, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2872, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1551, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3606, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3722, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3838, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3098, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2217, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2883, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2699, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4100, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2659, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3180, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4121, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2411, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2382, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3587, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4102, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3010, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2451, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3904, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2417, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4036, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3864, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1705, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3908, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2869, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3649, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2566, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3675, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2982, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2873, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2489, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4015, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1737, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3861, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3879, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3655, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3540, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2368, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3885, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2332, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3037, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3116, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2502, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3104, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3744, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3895, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1626, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2897, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2871, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1537, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4075, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2881, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2396, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2280, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4090, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4012, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1574, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4049, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2487, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3109, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2936, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3764, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3090, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3686, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2498, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2647, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2659, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3612, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2519, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2896, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2214, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1562, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3650, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3883, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3990, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2672, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3705, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2415, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2597, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3856, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2374, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4101, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1455, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1282, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4144, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1744, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2432, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4091, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2888, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3889, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3499, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2975, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2199, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2525, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1600, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3701, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3760, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3471, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3879, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3691, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4108, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2484, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3646, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1671, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2689, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2604, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2373, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3895, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4163, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3061, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2343, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3825, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2363, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3813, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3612, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2517, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3706, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3796, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3963, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2825, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3054, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3759, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3055, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4067, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2812, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2685, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2942, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3936, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3978, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3135, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2895, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4079, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3995, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2281, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3007, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3060, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3806, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3128, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3106, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2857, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4067, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3665, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3627, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2994, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4107, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2376, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4157, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2959, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2877, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1723, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3138, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4044, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1690, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3701, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3805, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2581, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4145, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3952, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2799, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2293, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2147, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3924, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1648, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3904, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1492, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3810, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4149, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2859, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2582, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2822, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2327, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2968, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3855, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3790, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4018, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2573, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2514, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4133, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2372, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1734, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4084, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4060, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3881, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3109, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4038, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1585, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3772, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3809, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3755, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2291, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1474, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3959, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2876, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2615, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2574, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3893, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3896, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1497, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3807, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4168, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2437, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4055, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4037, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3831, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2429, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2551, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2409, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1637, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2903, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3830, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2952, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2507, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3729, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2480, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3872, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2870, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3830, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2449, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3687, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4047, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2847, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2846, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1613, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3930, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2980, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4013, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2816, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1409, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3925, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2846, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4078, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4145, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3031, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4014, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2947, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2581, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3602, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2902, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4101, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2572, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3002, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2363, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2616, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3135, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3403, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3732, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3947, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2305, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3021, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2858, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3628, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2880, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3889, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2618, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3716, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1636, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3607, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3942, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3992, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2528, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3953, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1435, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4028, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2374, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3969, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2807, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2436, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2807, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3976, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1557, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3696, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4134, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2416, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4101, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4158, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2346, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3021, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2371, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2614, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2924, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3007, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2535, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2866, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3090, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4127, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3823, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3597, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3768, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2541, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1590, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3817, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2910, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2455, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1577, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3651, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1361, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4187, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4027, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3557, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3061, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4062, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4059, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3678, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2876, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3143, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4016, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3806, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2521, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2383, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2451, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2485, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1646, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2568, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4053, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4158, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3854, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2817, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3766, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1434, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1585, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3652, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2882, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3713, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2865, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4150, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3811, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3784, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2760, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3092, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2955, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1645, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3877, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3038, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3033, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2732, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3714, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2579, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3915, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2319, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1595, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3615, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3146, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2992, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2558, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3733, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2380, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2197, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2423, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2621, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2520, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3186, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3727, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2487, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2501, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4015, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4020, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3532, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4184, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2881, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4086, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4011, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2806, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2268, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3147, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2330, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1746, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2886, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4123, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2541, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3592, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2400, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1505, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3701, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2955, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3766, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2556, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3860, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1486, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3993, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2915, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2578, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3747, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2906, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2924, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2315, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1412, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1615, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3821, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3913, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3839, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3793, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2439, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1641, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2432, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2358, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4116, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3985, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1628, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2440, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3852, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3032, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1549, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2388, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4082, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2390, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2560, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4128, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2846, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3117, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3694, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1476, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3999, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2559, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1509, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2492, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3068, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3956, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3825, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3657, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3093, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1470, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3582, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3110, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2806, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2358, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3131, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3927, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3100, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1321, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1521, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3085, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2264, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3789, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2527, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3041, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3851, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1927, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3677, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3972, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1650, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3893, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2565, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2776, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1500, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1508, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2584, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2546, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3729, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2421, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2502, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3779, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3833, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3650, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3676, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3845, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3649, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3894, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3830, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2421, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2878, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3913, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3987, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2860, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2747, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2484, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3922, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3043, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2507, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4026, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1600, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1680, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4012, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3746, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3836, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2418, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3669, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1724, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2637, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3617, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2875, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3765, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2964, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2459, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1740, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3876, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4177, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2291, grad_fn=<NllLossBackward>)
# ok
# ...
# ok
# tensor(2.1803, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2637, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3810, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3602, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2584, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3146, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2964, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2785, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3721, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2540, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3069, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2435, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2712, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2406, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4146, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3733, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2515, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1730, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1727, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2608, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3495, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3671, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2469, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4002, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3108, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1552, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2791, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2884, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2263, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2381, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4055, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3658, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3955, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3694, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4113, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2931, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4039, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2883, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3855, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2915, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2484, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4060, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1510, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4150, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2545, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4208, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3863, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2497, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3853, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1667, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2673, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1647, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3173, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2865, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2344, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2662, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4095, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2837, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4058, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4025, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3884, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2305, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2806, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2263, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2354, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2823, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4120, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2757, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3067, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1465, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4157, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2900, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2341, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2310, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2988, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3047, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3851, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3720, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2946, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2542, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3177, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2462, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3776, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4043, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3993, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3716, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3920, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2312, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2979, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4072, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3778, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3014, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2567, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3852, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1482, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3674, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2534, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2279, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2446, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1616, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3643, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3781, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2610, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3710, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2529, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4053, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2266, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2968, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3605, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2406, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3719, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2577, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2825, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3682, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2578, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2413, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2580, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3878, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1753, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3964, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4210, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2359, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4082, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2873, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3020, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3933, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4130, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2455, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2436, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2538, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2384, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4086, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2372, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3574, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4063, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4203, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3728, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4022, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3984, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3087, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3830, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3150, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1398, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3812, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3066, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2348, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3219, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4012, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1516, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3935, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2410, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1480, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2909, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2932, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1555, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3771, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2616, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1625, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2591, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4112, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1502, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1577, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3605, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3170, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1671, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3423, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1589, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3108, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2677, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1667, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2537, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2536, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3608, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2374, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4021, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2576, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2617, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1707, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4087, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2502, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4028, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2226, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2628, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1666, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4140, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4057, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2884, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3023, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2917, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3939, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4080, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2733, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3619, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4086, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2522, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3865, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1549, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2684, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2426, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3079, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2434, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3907, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2599, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2939, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3896, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2387, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2641, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2344, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2898, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2670, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2479, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4157, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3873, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2418, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3812, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3762, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3800, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3013, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1519, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1460, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3081, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2351, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2912, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3959, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2302, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2282, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4014, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3972, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2430, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2687, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3762, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2563, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2892, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2814, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2303, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1499, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2847, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2410, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3019, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4006, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2813, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2534, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2994, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4080, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2483, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4040, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1454, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3919, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4131, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2967, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2329, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2960, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3145, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3481, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3914, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3792, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2450, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2011, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1764, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1612, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3107, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1667, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3936, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3895, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2536, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2870, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2957, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4071, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1835, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4045, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2482, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4022, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3794, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2705, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2624, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2764, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3953, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3945, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3641, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2294, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2759, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2991, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3066, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2541, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3134, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2818, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4087, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1735, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2933, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3971, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2477, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2597, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3946, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1439, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2884, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2975, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2866, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2850, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2539, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3615, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3066, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3758, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3672, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2670, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2667, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2876, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2516, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3002, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2614, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2703, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2310, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3985, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3872, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3695, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3975, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3110, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3974, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4037, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3852, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3638, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3652, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3797, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4105, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2475, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4162, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2460, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1666, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2814, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2784, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2568, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2859, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3654, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2335, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4031, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3958, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2485, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2833, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2608, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3113, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2510, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3036, grad_fn=<NllLossBackward>)
# ok
# tensor(2.4174, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2915, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2390, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3706, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2703, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3607, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3058, grad_fn=<NllLossBackward>)
# ok
# tensor(2.3701, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2504, grad_fn=<NllLossBackward>)
# ok
# tensor(2.1349, grad_fn=<NllLossBackward>)
# ok
# tensor(2.2897, grad_fn=<NllLossBackward>)
# ok
